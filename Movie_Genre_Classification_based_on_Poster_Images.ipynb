# %% [markdown]
# <a href="https://colab.research.google.com/github/datasigntist/deeplearning/blob/master/Movie_Genre_Classification_based_on_Poster_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Experiments with CNN -- Movie Genre Classification based on Poster Images**
#
# Author : Vishwanathan Raman
#
# EmailId : datasigntist@gmail.com
#
# Description :
#
# In this notebook we are going to develop a deep neural network (CNN) to solve the problem of movie genre classification based on movie poster images.
#
# Data Source : https://www.cs.ccu.edu.tw/~wtchu/projects/MoviePoster/index.html
#
# The following is the video articulating the concepts
# https://www.youtube.com/playlist?list=PLkEQhv7sdYRJydMA3U4HEKod-7DgMQEyy
#
# Reference Links:
#
# If you are new to Convolution and Pooling concepts
#
# *   Play with this notebook https://colab.research.google.com/drive/1_s6r49qhhk6kDCCDhKYsnBU_fjiQILB0 which gives you a view of how Convolution and Pooling works
#
# *   Please also go through the videos by Andrew NG at
# https://www.youtube.com/playlist?list=PLkDaE6sCZn6Gl29AoE31iwdVwSG-KnDzF . The playlist is long but you can hop onto this experiment once you are done till C4W1L11, that will give you a good foundation on Convolution and Pooling

# %% [markdown]
# # **Tensorflow Installation (Optional)**
#
# This experiment is built on tensorflow 2.0 gpu, run a quick check to see the current version, if its not 2.0 then uninstall the current version and install the 2.0 gpu version

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.14.0

# %%
# !pip uninstall tensorflow
# Out:
# Uninstalling tensorflow-1.14.0:
#   Would remove:
#     /usr/local/bin/freeze_graph
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-1.14.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-1.14.0

# %%
# !pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Downloading https://files.pythonhosted.org/packages/25/44/47f0722aea081697143fbcf5d2aa60d1aee4aaacb5869aee2b568974777b/tensorflow_gpu-2.0.0-cp36-cp36m-manylinux2010_x86_64.whl (380.8MB)
#      |████████████████████████████████| 380.8MB 46kB/s
# Collecting tensorflow-estimator<2.1.0,>=2.0.0 (from tensorflow-gpu)
#   Downloading https://files.pythonhosted.org/packages/95/00/5e6cdf86190a70d7382d320b2b04e4ff0f8191a37d90a422a2f8ff0705bb/tensorflow_estimator-2.0.0-py2.py3-none-any.whl (449kB)
#      |████████████████████████████████| 450kB 41.5MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.33.6)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.0.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.7.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.16.5)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.0.8)
# Collecting tensorboard<2.1.0,>=2.0.0 (from tensorflow-gpu)
#   Downloading https://files.pythonhosted.org/packages/9b/a6/e8ffa4e2ddb216449d34cfcb825ebb38206bee5c4553d69e7bc8bc2c5d64/tensorboard-2.0.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 35.2MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.11.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.8.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.1.7)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.12.0)
# Collecting gast==0.2.2 (from tensorflow-gpu)
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu) (41.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu) (2.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu) (0.16.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=4f1a7af9f1505e872930bf66f66f98e75b04358f97024ab659c356231e116398
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, gast, tensorflow-gpu
#   Found existing installation: tensorflow-estimator 1.14.0
#     Uninstalling tensorflow-estimator-1.14.0:
#       Successfully uninstalled tensorflow-estimator-1.14.0
#   Found existing installation: tensorboard 1.14.0
#     Uninstalling tensorboard-1.14.0:
#       Successfully uninstalled tensorboard-1.14.0
#   Found existing installation: gast 0.3.2
#     Uninstalling gast-0.3.2:
#       Successfully uninstalled gast-0.3.2
# Successfully installed gast-0.2.2 tensorboard-2.0.0 tensorflow-estimator-2.0.0 tensorflow-gpu-2.0.0

# %% [markdown]
# # **Importing Libraries**

# %%
import os
import zipfile
import random
import tensorflow as tf
import shutil
import csv
import numpy as np
from tensorflow.keras.optimizers import RMSprop
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile
import pandas as pd
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # **Dataset**
#
# The dataset is sourced from https://www.cs.ccu.edu.tw/~wtchu/projects/MoviePoster/index.html . This is relatively large dataset. The best way to access this dataset is to download and upload it to your google drive. If you try uploading it google colab directly it might take ages for you to upload hence google drive is the best option. Once uploaded to google drive, access the google drive from google colab seamless through a library. The dataset can then be downloaded to google colab tmp directory through wget.
#
# There are 2 datasets
#
# 1.   Metadata
# 2.   Poster Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/Data Dumps/Movie Posters'
# Out:
# Movie_Poster_Dataset.zip  Movie_Poster_Metadata.zip

# %% [markdown]
# ## **Downloading Moster Poster Metadata**

# %%
metadata_dir = '/tmp/moviepostersmetadata'
os.mkdir(metadata_dir)

# %%
local_zip = '/content/drive/My Drive/Data Dumps/Movie Posters/Movie_Poster_Metadata.zip'
zip_ref   = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/moviepostersmetadata')
zip_ref.close()

# %% [markdown]
# ## **Building a Master File List**

# %%
# !ls '/tmp/moviepostersmetadata/groundtruth' > fileList.txt

# %%
fileList = []
with open("/content/fileList.txt") as f:
  for line in f:
    fileList.append(line.strip())

# %%
print("The number of files in metadata",len(fileList))
# Out:
# The number of files in metadata 36

# %% [markdown]
# ## **Donwnloading Movies Posters**
#
# All the movie posters have been placed in individual directories that reflect the year of the release

# %%
moviepostersdata_dir = '/tmp/moviepostersdata'
os.mkdir(moviepostersdata_dir)

# %%
local_zip = '/content/drive/My Drive/Data Dumps/Movie Posters/Movie_Poster_Dataset.zip'
zip_ref   = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/moviepostersdata')
zip_ref.close()

# %% [markdown]
# ## **Data Consolidation**
#
# A a single directory to consolidate all the posteres

# %%
allmoviepostersdata_dir = '/tmp/allmoviepostersdata'
os.mkdir(allmoviepostersdata_dir)

# %% [markdown]
# ## **Master File List Table**
#
# Iterate through all the metadata files and build a single master table. As you can see the that there are no posters for 1982 which needs be taken into account. Essentially there could be metadata for non existent poster files or there could be poster files for which there is no metadata. This data anomaly has to be factored in while processing the files.

# %%
moviePosterCount = []
movieYear = []
moviePosterFile = []
for loop in range(len(fileList)):
  dirName = os.path.join('/tmp/moviepostersdata/Movie_Poster_Dataset',fileList[loop].replace(".txt",""))
  imageFileList = os.listdir(dirName)
  print('DirName:',dirName,' Year:',fileList[loop].replace(".txt",""),':',len(imageFileList))
  moviePosterCount.append(len(imageFileList))
  movieYear.append(fileList[loop].replace(".txt",""))
  for file in imageFileList:
    moviePosterFile.append(file)
# Out:
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1980  Year: 1980 : 96
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1981  Year: 1981 : 89
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1982  Year: 1982 : 0
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1983  Year: 1983 : 114
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1984  Year: 1984 : 134
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1985  Year: 1985 : 150
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1986  Year: 1986 : 169
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1987  Year: 1987 : 187
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1988  Year: 1988 : 201
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1989  Year: 1989 : 180
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1990  Year: 1990 : 167
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1991  Year: 1991 : 171
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1992  Year: 1992 : 175
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1993  Year: 1993 : 192
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1994  Year: 1994 : 191
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1995  Year: 1995 : 206
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1996  Year: 1996 : 210
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1997  Year: 1997 : 204
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1998  Year: 1998 : 204
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/1999  Year: 1999 : 226
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2000  Year: 2000 : 237
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2001  Year: 2001 : 213
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2002  Year: 2002 : 249
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2003  Year: 2003 : 247
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2004  Year: 2004 : 295
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2005  Year: 2005 : 282
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2006  Year: 2006 : 327
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2007  Year: 2007 : 319
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2008  Year: 2008 : 318
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2009  Year: 2009 : 284
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2010  Year: 2010 : 273
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2011  Year: 2011 : 311
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2012  Year: 2012 : 351
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2013  Year: 2013 : 387
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2014  Year: 2014 : 350
# DirName: /tmp/moviepostersdata/Movie_Poster_Dataset/2015  Year: 2015 : 343

# %%
movieListDatabase = pd.DataFrame({'MovieYear':movieYear,'MoviePosterCount':moviePosterCount})

# %%
movieListDatabase.head()
# Out:
#   MovieYear  MoviePosterCount
# 0      1980                96
# 1      1981                89
# 2      1982                 0
# 3      1983               114
# 4      1984               134

# %%
print("As per the metadata there has to be ",movieListDatabase["MoviePosterCount"].sum()," movie posters")
# Out:
# As per the metadata there has to be  8052  movie posters

# %% [markdown]
# ## **Iterating through the Metadata to extract other relevant information**
#
# Here is a quick and dirty version of reading the corresponding metadata files. During exploratory analysis, found some differences in the file metadata. Prior to 1982 the files could be read using "utf-8" while others could be read only using "utf-16". This is not the best code but serves the purpose of collecting relevant information.

# %%
movieList = []
movieDict ={}
count = 0
for loop in range(len(fileList)):
  recCount = 0
  if (movieListDatabase["MoviePosterCount"][loop]>0):
    recCount = 0
    fileName = os.path.join('/tmp/moviepostersmetadata/groundtruth',fileList[loop])
    try:
      with open(fileName,encoding='utf-8') as f:
          for line in f:
            modline = line.strip()
            if (modline=="{"):
              movieDict["Year"] = fileList[loop].replace(".txt","").strip()
              count = count+1
            elif (modline=="}"):
              movieList.append(movieDict)
              movieDict ={}
              count = count-1
            else:
              movieDict[modline.split(":")[0].replace('"', '').strip()] = modline.split(":")[1].replace('"', '').strip()
              recCount = recCount+1
    except:
        with open(fileName,encoding='utf-16') as f:
          for line in f:
            modline = line.strip()
            if (modline=="{"):
              movieDict["Year"] = fileList[loop].replace(".txt","").strip()
              count = count+1
            elif (modline=="}"):
              movieList.append(movieDict)
              movieDict ={}
              count = count-1
            else:
              movieDict[modline.split(":")[0].replace('"', '').strip()] = modline.split(":")[1].replace('"', '').strip()
              recCount = recCount+1

# %%
movieList[1]
# Out:
# {'Actors': 'Gene Wilder, Richard Pryor, Georg Stanford Brown, JoBeth Williams,',
#  'Awards': '1 nomination.,',
#  'Box_office': '101,500,000,',
#  'Country': 'USA,',
#  'Director': 'Sidney Poitier,',
#  'Genre': 'Comedy, Crime,',
#  'Language': 'English,',
#  'Metascore': '50',
#  'Poster': 'http',
#  'Rated': 'R,',
#  'Released': '12 Dec 1980,',
#  'Response': 'True,',
#  'Runtime': '111 min,',
#  'Title': 'Stir Crazy,',
#  'Type': 'movie,',
#  'Writer': 'Bruce Jay Friedman,',
#  'Year': '1980',
#  '_id': 'ObjectId(56fb860e71a0651b0c306f56),',
#  'imdbID': 'tt0081562,',
#  'imdbRating': '6.8,',
#  'imdbVotes': '17,705,'}

# %% [markdown]
# ## **Building the database of actual existent files**

# %% [markdown]
# Iterates through the movieList and find if there is a corresponding movie poster file existent. If its existent it moves them to the new directory that was created to place all the movie posters.

# %%
mainPosterDirectory = '/tmp/moviepostersdata/Movie_Poster_Dataset'
allmoviepostersdata_dir = '/tmp/allmoviepostersdata'
scrubbedMovieList = []
newFileList = []
for loop in range(len(movieList)):
  filePosterDirectory = os.path.join(mainPosterDirectory,movieList[loop]['Year'])
  fileName = movieList[loop]["imdbID"].replace(",","").strip()
  actualFileName = os.path.join(filePosterDirectory,fileName)+".jpg"
  if (len([file for file in newFileList if file==fileName])==0):
    newFileList.append(fileName)
    if(os.path.isfile(actualFileName)):
      scrubbedMovieList.append(movieList[loop])
      destFileName = movieList[loop]["imdbID"].replace(",","").strip()+".jpg"
      destFileNameWithPath = os.path.join(allmoviepostersdata_dir,destFileName)
      shutil.copyfile(actualFileName,destFileNameWithPath)

# %%
print("Size of scrubbedMovieList is ",len(scrubbedMovieList))
# Out:
# Size of scrubbedMovieList is  8052

# %%
allGenreList = []
for loop in range(len(scrubbedMovieList)):
  allGenreList.append(','.join([elem for elem in scrubbedMovieList[loop]['Genre'].split(",") if elem!=""]))

# %%
print(allGenreList)
# Out:
# ['Action, Adventure, Fantasy', 'Comedy, Crime', 'Comedy', 'Action, Comedy', 'Comedy, War', 'Biography, Drama, Music', 'Action, Comedy', 'Adventure, Drama, Romance', 'Action, Comedy, Crime', 'Drama', 'Adventure, Comedy, Family', 'Drama, Romance, Western', 'Drama, Horror', 'Comedy, Romance', 'Comedy, Crime, Sci-Fi', 'Comedy, Sport', 'Drama', 'Comedy, Drama', 'Mystery, Thriller', 'Drama, Music, Romance', 'Action, Adventure, Sci-Fi', 'Biography, Drama', 'Action, Adventure, Comedy', 'Biography, Drama, Sport', 'Fantasy, Musical, Romance', 'Crime, Drama, Mystery', 'Comedy, Drama, Family', 'Fantasy, Horror', 'Horror, Sci-Fi, Thriller', 'Crime, Mystery, Thriller', 'Action, Drama, Romance', 'Music, Romance, Drama', 'Adventure, Comedy, Family', 'Adventure, Comedy, Crime', 'Action, Sci-Fi', 'Action, Biography, Comedy', 'Comedy, Romance', 'Western', 'Comedy', 'Horror, Romance', 'Comedy, Crime, Mystery', 'Comedy, Fantasy', 'Drama, Romance, Music', 'Comedy, Fantasy, History', 'Comedy', 'Comedy', 'Crime, Mystery, Thriller', 'Adventure, Family', 'Comedy', 'Comedy, Drama', 'Comedy', 'Comedy', 'Drama, Fantasy, Romance', 'Comedy, Drama', 'Adventure, Sci-Fi, Thriller', 'Crime, Thriller', 'Horror', 'Comedy, Drama, Romance', 'Drama', 'Drama, War', 'Action, Comedy, Drama', 'Biography, Comedy', 'Comedy', 'Comedy, Horror, Thriller', 'Comedy, Drama, Romance', 'Comedy, Crime, Fantasy', 'Documentary, Comedy, Music', 'Horror, Thriller', 'Comedy, Drama, Romance', 'Comedy, Drama, Romance', 'Comedy, Drama', 'Comedy, Musical', 'Crime, Drama, Thriller', 'Drama, History, War', 'Drama, Fantasy', 'Drama', 'Action, Adventure, Drama', 'Adventure, Drama, Western', 'Family, Comedy', 'Comedy', 'Biography, Drama, Music', 'Crime, Romance, Comedy', 'Comedy, Documentary', 'Drama, Thriller', 'Comedy, Romance', 'Animation, Comedy, Family', 'Drama', 'Biography, Drama, Music', 'Drama', 'Drama', 'Comedy, Romance', 'Drama', 'Romance, Comedy', 'Comedy', 'Drama, Horror, Thriller', 'Drama, Musical', 'Action, Adventure', 'Drama', 'Comedy, Romance', 'Action, Comedy, War', 'Action, Comedy, Sport', 'Biography, Drama, Sport', 'Action, Adventure, Thriller', 'Comedy, Drama', 'Adventure, Comedy, Fantasy', 'Drama, Romance, Thriller', 'Biography, Drama, History', 'Animation, Adventure, Drama', 'Adventure', 'Drama', 'Action, Crime, Drama', 'Adventure, Drama, Fantasy', 'Comedy', 'Comedy', 'Comedy, Crime, Family', 'Drama, Romance', 'Comedy, Fantasy, Horror', 'Crime, Drama', 'Drama, Romance', 'Comedy', 'Comedy, Fantasy, Sci-Fi', 'Horror', 'Comedy, Drama', 'Action, Sci-Fi', 'Crime, Drama, Thriller', 'Drama, Horror, Thriller', 'Horror, Mystery, Thriller', 'Comedy, Sci-Fi', 'Biography, Drama', 'Comedy, Romance', 'Comedy', 'Horror', 'Romance, Thriller, War', 'Comedy', 'Action, Crime, Sci-Fi', 'Comedy, Family, Fantasy', 'Comedy, Sci-Fi', 'Comedy, Romance', 'Drama, Music', 'Action, Crime, Thriller', 'Comedy', 'Drama', 'Action, Adventure, Fantasy', 'Crime, Drama', 'Action, Adventure, Western', 'Comedy, Drama', 'Crime, Drama, Thriller', 'Western', 'Drama, Mystery, Thriller', 'Adventure, Comedy, Romance', 'Action, Crime, Drama', 'Drama', 'Action, Drama, Sport', 'Drama, Mystery, Romance', 'Horror, Thriller', 'Comedy', 'Drama, Musical, Romance', 'Horror', 'Drama', 'Crime, Drama', 'Comedy', 'Comedy, Drama, Sport', 'Romance, Thriller', 'Adventure, Drama, History', 'Comedy, Crime, Family', 'Comedy, Horror', 'Comedy, Drama, Romance', 'Adventure, Crime, Thriller', 'Drama, Musical', 'Comedy, Romance', 'Drama, Horror, Thriller', 'Sci-Fi, Comedy', 'Biography, Music', 'Adventure, Mystery, Thriller', 'Action, Comedy', 'Drama', 'Drama', 'Crime, Drama, Mystery', 'Drama', 'Documentary, Music', 'Horror, Mystery', 'Horror, Thriller', 'Drama', 'Drama, History', 'Comedy', 'Comedy, Drama', 'Drama, Romance, Music', 'Comedy', 'Sci-Fi, Thriller', 'Action, Adventure, Thriller', 'Action, Thriller', 'Drama, Music, Romance', 'Comedy, Drama', 'Comedy, Crime, Drama', 'Adventure, Comedy', 'Action, Comedy, Sci-Fi', 'Comedy, Drama', 'A ...

# %%
fileNameList =[elem["imdbID"].replace(",","").strip()+".jpg" for elem in scrubbedMovieList]

# %%
print(fileNameList)
# Out:
# ['tt0080684.jpg', 'tt0081562.jpg', 'tt0080339.jpg', 'tt0080377.jpg', 'tt0081375.jpg', 'tt0080549.jpg', 'tt0081529.jpg', 'tt0080453.jpg', 'tt0080455.jpg', 'tt0081283.jpg', 'tt0081353.jpg', 'tt0081696.jpg', 'tt0081505.jpg', 'tt0081480.jpg', 'tt0080520.jpg', 'tt0080487.jpg', 'tt0080474.jpg', 'tt0081060.jpg', 'tt0080661.jpg', 'tt0080948.jpg', 'tt0080745.jpg', 'tt0080678.jpg', 'tt0080472.jpg', 'tt0081398.jpg', 'tt0081777.jpg', 'tt0080365.jpg', 'tt0081207.jpg', 'tt0080749.jpg', 'tt0080360.jpg', 'tt0080569.jpg', 'tt0081259.jpg', 'tt0080888.jpg', 'tt0080861.jpg', 'tt0081439.jpg', 'tt0080736.jpg', 'tt0080907.jpg', 'tt0080863.jpg', 'tt0081071.jpg', 'tt0080739.jpg', 'tt0081383.jpg', 'tt0081249.jpg', 'tt0081268.jpg', 'tt0080556.jpg', 'tt0081751.jpg', 'tt0081032.jpg', 'tt0081698.jpg', 'tt0081163.jpg', 'tt0081031.jpg', 'tt0080731.jpg', 'tt0081554.jpg', 'tt0080881.jpg', 'tt0081485.jpg', 'tt0081534.jpg', 'tt0081656.jpg', 'tt0079285.jpg', 'tt0080754.jpg', 'tt0080402.jpg', 'tt0080724.jpg', 'tt0080756.jpg', 'tt0080437.jpg', 'tt0081568.jpg', 'tt0081748.jpg', 'tt0080808.jpg', 'tt0081184.jpg', 'tt0081063.jpg', 'tt0081269.jpg', 'tt0080634.jpg', 'tt0080850.jpg', 'tt0080550.jpg', 'tt0081758.jpg', 'tt0081150.jpg', 'tt0081433.jpg', 'tt0080798.jpg', 'tt0080979.jpg', 'tt0081414.jpg', 'tt0080868.jpg', 'tt0081747.jpg', 'tt0080855.jpg', 'tt0081159.jpg', 'tt0081080.jpg', 'tt0080913.jpg', 'tt0080442.jpg', 'tt0080790.jpg', 'tt0081759.jpg', 'tt0080975.jpg', 'tt0080461.jpg', 'tt0080500.jpg', 'tt0081235.jpg', 'tt0080854.jpg', 'tt0081280.jpg', 'tt0081625.jpg', 'tt0081528.jpg', 'tt0081044.jpg', 'tt0079302.jpg', 'tt0081334.jpg', 'tt0080469.jpg', 'tt0082971.jpg', 'tt0082846.jpg', 'tt0082031.jpg', 'tt0083131.jpg', 'tt0082136.jpg', 'tt0082158.jpg', 'tt0082398.jpg', 'tt0082405.jpg', 'tt0081633.jpg', 'tt0081974.jpg', 'tt0082979.jpg', 'tt0082406.jpg', 'tt0083170.jpg', 'tt0083169.jpg', 'tt0083064.jpg', 'tt0082348.jpg', 'tt0082517.jpg', 'tt0082121.jpg', 'tt0082474.jpg', 'tt0082329.jpg', 'tt0082010.jpg', 'tt0082402.jpg', 'tt0082416.jpg', 'tt0082948.jpg', 'tt0082763.jpg', 'tt0082495.jpg', 'tt0082853.jpg', 'tt0082340.jpg', 'tt0082089.jpg', 'tt0082449.jpg', 'tt0082418.jpg', 'tt0082558.jpg', 'tt0082766.jpg', 'tt0082886.jpg', 'tt0083254.jpg', 'tt0082533.jpg', 'tt0082351.jpg', 'tt0083163.jpg', 'tt0082869.jpg', 'tt0082263.jpg', 'tt0082146.jpg', 'tt0082200.jpg', 'tt0082816.jpg', 'tt0082817.jpg', 'tt0083015.jpg', 'tt0082992.jpg', 'tt0082288.jpg', 'tt0083232.jpg', 'tt0082648.jpg', 'tt0082382.jpg', 'tt0082934.jpg', 'tt0082193.jpg', 'tt0082085.jpg', 'tt0082042.jpg', 'tt0083190.jpg', 'tt0082970.jpg', 'tt0083284.jpg', 'tt0083006.jpg', 'tt0083336.jpg', 'tt0082138.jpg', 'tt0082894.jpg', 'tt0082245.jpg', 'tt0083326.jpg', 'tt0082945.jpg', 'tt0082111.jpg', 'tt0081964.jpg', 'tt0082353.jpg', 'tt0082432.jpg', 'tt0082457.jpg', 'tt0083133.jpg', 'tt0082001.jpg', 'tt0082958.jpg', 'tt0083365.jpg', 'tt0082764.jpg', 'tt0082497.jpg', 'tt0082507.jpg', 'tt0083193.jpg', 'tt0083113.jpg', 'tt0082525.jpg', 'tt0082969.jpg', 'tt0082619.jpg', 'tt0082220.jpg', 'tt0083079.jpg', 'tt0080762.jpg', 'tt0082812.jpg', 'tt0082352.jpg', 'tt0082499.jpg', 'tt0082222.jpg', 'tt0083041.jpg', 'tt0086425.jpg', 'tt0085549.jpg', 'tt0086465.jpg', 'tt0086567.jpg', 'tt0086034.jpg', 'tt0086383.jpg', 'tt0086361.jpg', 'tt0085970.jpg', 'tt0086200.jpg', 'tt0085995.jpg', 'tt0086393.jpg', 'tt0085244.jpg', 'tt0086006.jpg', 'tt0085750.jpg', 'tt0085255.jpg', 'tt0086619.jpg', 'tt0086312.jpg', 'tt0086154.jpg', 'tt0086129.jpg', 'tt0086508.jpg', 'tt0086005.jpg', 'tt0086491.jpg', 'tt0085470.jpg', 'tt0085678.jpg', 'tt0086066.jpg', 'tt0086352.jpg', 'tt0086494.jpg', 'tt0085980.jpg', 'tt0085346.jpg', 'tt0086197.jpg', 'tt0085382.jpg', 'tt0085333.jpg', 'tt0085407.jpg', 'tt0085276.jpg', 'tt0085334.jpg', 'tt0085919.jpg', 'tt0086525.jpg', 'tt0085154.jpg', 'tt0085811.jpg', 'tt0086346.jpg', 'tt0085387.jpg', 'tt0085615.jpg', 'tt0085478.jpg', 'tt0086143.jpg', 'tt0086397.jpg', 'tt0086192.jpg', 'tt0086379.jpg', 'tt0085862.jpg', 'tt0085248.jpg', 'tt0087127.jpg', 'tt0 ...

# %%
movieListDatabase = pd.DataFrame({'FileNames':fileNameList,'Genres':allGenreList})

# %%
movieListDatabase.head()
# Out:
#        FileNames                      Genres
# 0  tt0080684.jpg  Action, Adventure, Fantasy
# 1  tt0081562.jpg               Comedy, Crime
# 2  tt0080339.jpg                      Comedy
# 3  tt0080377.jpg              Action, Comedy
# 4  tt0081375.jpg                 Comedy, War

# %%
movieListDatabase["Genres"]=movieListDatabase["Genres"].apply(lambda x:x.split(","))

# %%
movieListDatabase.head()
# Out:
#        FileNames                          Genres
# 0  tt0080684.jpg  [Action,  Adventure,  Fantasy]
# 1  tt0081562.jpg                [Comedy,  Crime]
# 2  tt0080339.jpg                        [Comedy]
# 3  tt0080377.jpg               [Action,  Comedy]
# 4  tt0081375.jpg                  [Comedy,  War]

# %%
genreList = ""
for loop in range(len(scrubbedMovieList)):
  if (genreList==""):
    genreList = scrubbedMovieList[loop]['Genre']
  else:
    genreList = genreList+","+scrubbedMovieList[loop]['Genre']

# %%
genreSet = [elem.strip() for elem in genreList.split(',') if elem!=""]

# %%
genreSet = set(genreSet)

# %%
genreSetList = list(genreSet)

# %%
genreSetList.sort()

# %%
print(genreSetList)
# Out:
# ['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'N/A', 'News', 'Reality-TV', 'Romance', 'Sci-Fi', 'Short', 'Sport', 'Thriller', 'War', 'Western']

# %% [markdown]
# ## **Creating a movie list having 1 Genre**
#
# Selecting the 1st Genre as Genre of the movie

# %%
movieListDatabase1Genre = movieListDatabase

# %%
movieListDatabase1Genre["Genres"] = [elem[0] for elem in movieListDatabase["Genres"]]

# %%
movieListDatabase1GenreStats = movieListDatabase1Genre.groupby("Genres").size().reset_index(name="counts")

# %%
movieListDatabase1GenreStats = movieListDatabase1GenreStats.sort_values("counts",ascending=False)

# %%
movieListDatabase1GenreStats
# Out:
#          Genres  counts
# 4        Comedy    2409
# 7         Drama    1565
# 0        Action    1392
# 6   Documentary     729
# 5         Crime     444
# 1     Adventure     359
# 3     Biography     336
# 2     Animation     264
# 11       Horror     249
# 9       Fantasy      60
# 22     Thriller      46
# 20        Short      42
# 14      Mystery      33
# 18      Romance      31
# 8        Family      28
# 19       Sci-Fi      17
# 13      Musical      12
# 15          N/A      11
# 12        Music       8
# 24      Western       7
# 23          War       5
# 10      History       2
# 17   Reality-TV       1
# 16         News       1
# 21        Sport       1

# %%
listForFilter = list(movieListDatabase1GenreStats[movieListDatabase1GenreStats["counts"]>100]["Genres"])

# %%
movieListDatabase1GenreFiltered = movieListDatabase1Genre[movieListDatabase1Genre["Genres"].isin(listForFilter)]

# %%
movieListDatabase1GenreFiltered.shape
# Out:
# (7747, 2)

# %%
sampleForValidation = movieListDatabase1GenreFiltered.groupby('Genres').apply(lambda x: x.sample(frac=.005))

# %%
fileListForValidation = [fileName for fileName in sampleForValidation["FileNames"]]

# %%
len(fileListForValidation)
# Out:
# 39

# %%
validationData = movieListDatabase1GenreFiltered[movieListDatabase1GenreFiltered["FileNames"].isin(fileListForValidation)]

# %%
validationData.shape
# Out:
# (39, 2)

# %%
validationData.tail(10)
# Out:
#           FileNames       Genres
# 6687  tt1855199.jpg        Crime
# 6784  tt2178508.jpg       Action
# 7015  tt2334879.jpg       Action
# 7169  tt2436516.jpg       Action
# 7211  tt2016940.jpg       Action
# 7290  tt2419284.jpg  Documentary
# 7618  tt3093520.jpg  Documentary
# 7817  tt3863552.jpg       Comedy
# 7828  tt1772288.jpg       Comedy
# 7893  tt4572856.jpg       Comedy

# %%
trainData = movieListDatabase1GenreFiltered[~movieListDatabase1GenreFiltered["FileNames"].isin(fileListForValidation)]

# %%
trainData.shape
# Out:
# (7708, 2)

# %%
movieListDatabase.shape
# Out:
# (8052, 2)

# %% [markdown]
# ## **Viewing the Posters and the respective Genres**

# %%
sampledMovies = movieListDatabase.sample(frac=.001)
maxCols = 4
maxRows = sampledMovies.shape[0]//maxCols
fig, axes = plt.subplots(nrows=maxRows, ncols=maxCols, figsize=(15,15))
row = 0
col = 0
for loop in range(sampledMovies.shape[0]):
    img_path = os.path.join(allmoviepostersdata_dir,sampledMovies.iloc[loop]["FileNames"])
    img = mpimg.imread(img_path)
    if (col > (maxCols-1)):
      row = row + 1
      col = 0
    axes[row, col].axis("off")
    axes[row, col].set_title(sampledMovies.iloc[loop]["Genres"])
    axes[row, col].imshow(img)  
    col = col + 1
plt.subplots_adjust(wspace=.10, hspace=.10)
plt.show()

# %% [markdown]
# ## **Shuffling the dataset**

# %%
movieListDatabase = movieListDatabase.sample(frac=1).reset_index(drop=True)

# %%
movieListDatabase.head()
# Out:
#        FileNames                         Genres
# 0  tt3966404.jpg                        [Drama]
# 1  tt0087835.jpg             [Comedy,  Fantasy]
# 2  tt0120856.jpg  [Action,  Adventure,  Family]
# 3  tt1609479.jpg               [Comedy,  Drama]
# 4  tt0167261.jpg   [Action,  Adventure,  Drama]

# %% [markdown]
# # **Modelling**

# %%
train_datagen=ImageDataGenerator(rescale=1./255.)
valid_datagen=ImageDataGenerator(rescale=1./255.)
targetSize = 200

train_generator=train_datagen.flow_from_dataframe(
      dataframe=trainData,
      directory="/tmp/allmoviepostersdata",
      x_col="FileNames",
      y_col="Genres",
      batch_size=50,
      shuffle=True,
      class_mode="categorical",
      classes=listForFilter,
      target_size=(targetSize,targetSize)
)

valid_generator=valid_datagen.flow_from_dataframe(
      dataframe=validationData,
      directory="/tmp/allmoviepostersdata",
      x_col="FileNames",
      y_col="Genres",
      batch_size=10,
      shuffle=True,
      class_mode="categorical",
      classes=listForFilter,
      target_size=(targetSize,targetSize)
)
# Out:
# Found 7708 validated image filenames belonging to 9 classes.
# Found 39 validated image filenames belonging to 9 classes.

# %%
maxPooling = 4
filterSize = 3
nodeCount = 64
dropOut = 0.3

model = tf.keras.models.Sequential([                 
    tf.keras.layers.Conv2D(nodeCount, (filterSize, filterSize), activation='relu', input_shape=(targetSize, targetSize, 3), padding="valid"),
    tf.keras.layers.MaxPooling2D(maxPooling, maxPooling),    
    tf.keras.layers.Dropout(dropOut),                 
    tf.keras.layers.Conv2D(nodeCount, (filterSize, filterSize), activation='relu', input_shape=(targetSize, targetSize, 3), padding="valid"),
    tf.keras.layers.MaxPooling2D(maxPooling, maxPooling),       
    tf.keras.layers.Dropout(dropOut),                                         
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(nodeCount, activation=tf.nn.relu), 
    tf.keras.layers.Dense(len(listForFilter), activation=tf.nn.softmax)])

model.compile(optimizer = "adam",
              loss = 'categorical_crossentropy',
              metrics=['accuracy','categorical_crossentropy'])

# %%
model.summary()
# Out:
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_78 (Conv2D)           (None, 198, 198, 64)      1792
# _________________________________________________________________
# max_pooling2d_78 (MaxPooling (None, 49, 49, 64)        0
# _________________________________________________________________
# dropout_77 (Dropout)         (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_79 (Conv2D)           (None, 47, 47, 64)        36928
# _________________________________________________________________
# max_pooling2d_79 (MaxPooling (None, 11, 11, 64)        0
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 11, 11, 64)        0
# _________________________________________________________________
# flatten_36 (Flatten)         (None, 7744)              0
# _________________________________________________________________
# dense_66 (Dense)             (None, 64)                495680
# _________________________________________________________________
# dense_67 (Dense)             (None, 9)                 585
# =================================================================
# Total params: 534,985
# Trainable params: 534,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
print("STEP_SIZE_TRAIN :",STEP_SIZE_TRAIN)
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
print("STEP_SIZE_VALID :",STEP_SIZE_VALID)
history = model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=100
)
# Out:
# STEP_SIZE_TRAIN : 154
# STEP_SIZE_VALID : 3
# Epoch 1/100
# 154/154 [==============================] - 35s 227ms/step - loss: 1.8478 - accuracy: 0.3317 - categorical_crossentropy: 1.8479 - val_loss: 1.8687 - val_accuracy: 0.3333 - val_categorical_crossentropy: 1.8687
# Epoch 2/100
# 154/154 [==============================] - 34s 219ms/step - loss: 1.7902 - accuracy: 0.3638 - categorical_crossentropy: 1.7873 - val_loss: 1.8539 - val_accuracy: 0.2333 - val_categorical_crossentropy: 1.8539
# Epoch 3/100
# 154/154 [==============================] - 34s 219ms/step - loss: 1.7466 - accuracy: 0.3813 - categorical_crossentropy: 1.7479 - val_loss: 1.8681 - val_accuracy: 0.3333 - val_categorical_crossentropy: 1.8681
# Epoch 4/100
# 154/154 [==============================] - 34s 218ms/step - loss: 1.7033 - accuracy: 0.3961 - categorical_crossentropy: 1.7083 - val_loss: 1.8099 - val_accuracy: 0.3000 - val_categorical_crossentropy: 1.8099
# Epoch 5/100
# 154/154 [==============================] - 34s 218ms/step - loss: 1.6611 - accuracy: 0.4083 - categorical_crossentropy: 1.6627 - val_loss: 1.7864 - val_accuracy: 0.2667 - val_categorical_crossentropy: 1.7864
# Epoch 6/100
# 154/154 [==============================] - 34s 219ms/step - loss: 1.6127 - accuracy: 0.4258 - categorical_crossentropy: 1.6126 - val_loss: 1.7239 - val_accuracy: 0.2667 - val_categorical_crossentropy: 1.7239
# Epoch 7/100
# 154/154 [==============================] - 34s 221ms/step - loss: 1.5409 - accuracy: 0.4569 - categorical_crossentropy: 1.5383 - val_loss: 1.7050 - val_accuracy: 0.3333 - val_categorical_crossentropy: 1.7050
# Epoch 8/100
# 154/154 [==============================] - 34s 220ms/step - loss: 1.4698 - accuracy: 0.4764 - categorical_crossentropy: 1.4709 - val_loss: 1.6718 - val_accuracy: 0.4000 - val_categorical_crossentropy: 1.6718
# Epoch 9/100
# 154/154 [==============================] - 34s 220ms/step - loss: 1.3957 - accuracy: 0.5043 - categorical_crossentropy: 1.3941 - val_loss: 1.6986 - val_accuracy: 0.3333 - val_categorical_crossentropy: 1.6986
# Epoch 10/100
# 154/154 [==============================] - 34s 222ms/step - loss: 1.2982 - accuracy: 0.5337 - categorical_crossentropy: 1.2998 - val_loss: 1.7423 - val_accuracy: 0.3333 - val_categorical_crossentropy: 1.7423
# Epoch 11/100
# 154/154 [==============================] - 34s 221ms/step - loss: 1.1980 - accuracy: 0.5671 - categorical_crossentropy: 1.1981 - val_loss: 1.6792 - val_accuracy: 0.3667 - val_categorical_crossentropy: 1.6792
# Epoch 12/100
# 154/154 [==============================] - 34s 223ms/step - loss: 1.1224 - accuracy: 0.5939 - categorical_crossentropy: 1.1233 - val_loss: 1.7112 - val_accuracy: 0.3667 - val_categorical_crossentropy: 1.7112
# Epoch 13/100
# 154/154 [==============================] - 34s 222ms/step - loss: 1.0227 - accuracy: 0.6316 - categorical_crossentropy: 1.0240 - val_loss: 1.8135 - val_accuracy: 0.3333 - val_categorical_crossentropy: 1.8135
# Epoch 14/100
# 154/154 [==============================] - 34s 224ms/step - loss: 0.9367 - accuracy: 0.6613 - categorical_crossentropy: 0.9373 - val_loss: 1.7234 - val_accuracy: 0.4333 - val_categorical_crossentropy: 1.7234
# Epoch 15/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.8710 - accuracy: 0.6845 - categorical_crossentropy: 0.8711 - val_loss: 1.8664 - val_accuracy: 0.4000 - val_categorical_crossentropy: 1.8664
# Epoch 16/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.8077 - accuracy: 0.7085 - categorical_crossentropy: 0.8076 - val_loss: 1.9711 - val_accuracy: 0.5000 - val_categorical_crossentropy: 1.9711
# Epoch 17/100
# 154/154 [==============================] - 35s 224ms/step - loss: 0.7512 - accuracy: 0.7268 - categorical_crossentropy: 0.7512 - val_loss: 2.0256 - val_accuracy: 0.3333 - val_categorical_crossentropy: 2.0256
# Epoch 18/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.6816 - accuracy: 0.7565 - categorical_crossentropy: 0.6819 - val_loss: 2.1253 - val_accuracy: 0.4333 - val_categorical_crossentropy: 2.1253
# Epoch 19/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.6507 - accuracy: 0.7630 - categorical_crossentropy: 0.6491 - val_loss: 2.3580 - val_accuracy: 0.4000 - val_categorical_crossentropy: 2.3580
# Epoch 20/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.6138 - accuracy: 0.7809 - categorical_crossentropy: 0.6129 - val_loss: 2.4889 - val_accuracy: 0.3333 - val_categorical_crossentropy: 2.4889
# Epoch 21/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.5712 - accuracy: 0.7938 - categorical_crossentropy: 0.5731 - val_loss: 2.3794 - val_accuracy: 0.3667 - val_categorical_crossentropy: 2.3794
# Epoch 22/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.5289 - accuracy: 0.8087 - categorical_crossentropy: 0.5277 - val_loss: 2.8762 - val_accuracy: 0.4000 - val_categorical_crossentropy: 2.8762
# Epoch 23/100
# 154/154 [==============================] - 35s 224ms/step - loss: 0.5222 - accuracy: 0.8113 - categorical_crossentropy: 0.5198 - val_loss: 2.4168 - val_accuracy: 0.5000 - val_categorical_crossentropy: 2.4168
# Epoch 24/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.4988 - accuracy: 0.8191 - categorical_crossentropy: 0.4990 - val_loss: 2.4439 - val_accuracy: 0.3667 - val_categorical_crossentropy: 2.4439
# Epoch 25/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.4512 - accuracy: 0.8399 - categorical_crossentropy: 0.4486 - val_loss: 2.6709 - val_accuracy: 0.3000 - val_categorical_crossentropy: 2.6709
# Epoch 26/100
# 154/154 [==============================] - 34s 224ms/step - loss: 0.4231 - accuracy: 0.8486 - categorical_crossentropy: 0.4231 - val_loss: 2.8922 - val_accuracy: 0.4000 - val_categorical_crossentropy: 2.8922
# Epoch 27/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.4400 - accuracy: 0.8452 - categorical_crossentropy: 0.4410 - val_loss: 2.8565 - val_accuracy: 0.3667 - val_categorical_crossentropy: 2.8565
# Epoch 28/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.4041 - accuracy: 0.8560 - categorical_crossentropy: 0.4036 - val_loss: 2.9245 - val_accuracy: 0.5000 - val_categorical_crossentropy: 2.9245
# Epoch 29/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.3776 - accuracy: 0.8660 - categorical_crossentropy: 0.3776 - val_loss: 2.8172 - val_accuracy: 0.5000 - val_categorical_crossentropy: 2.8172
# Epoch 30/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.3701 - accuracy: 0.8658 - categorical_crossentropy: 0.3702 - val_loss: 2.7587 - val_accuracy: 0.3667 - val_categorical_crossentropy: 2.7587
# Epoch 31/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.3410 - accuracy: 0.8770 - categorical_crossentropy: 0.3415 - val_loss: 3.1051 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.1051
# Epoch 32/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.3540 - accuracy: 0.8733 - categorical_crossentropy: 0.3549 - val_loss: 2.9068 - val_accuracy: 0.4333 - val_categorical_crossentropy: 2.9068
# Epoch 33/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.3355 - accuracy: 0.8812 - categorical_crossentropy: 0.3352 - val_loss: 3.0761 - val_accuracy: 0.3667 - val_categorical_crossentropy: 3.0761
# Epoch 34/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.2972 - accuracy: 0.8961 - categorical_crossentropy: 0.2983 - val_loss: 3.2175 - val_accuracy: 0.3667 - val_categorical_crossentropy: 3.2175
# Epoch 35/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.3166 - accuracy: 0.8903 - categorical_crossentropy: 0.3181 - val_loss: 3.3196 - val_accuracy: 0.4000 - val_categorical_crossentropy: 3.3196
# Epoch 36/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.3048 - accuracy: 0.8926 - categorical_crossentropy: 0.3048 - val_loss: 3.0603 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.0603
# Epoch 37/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.2956 - accuracy: 0.8929 - categorical_crossentropy: 0.2977 - val_loss: 3.2538 - val_accuracy: 0.3667 - val_categorical_crossentropy: 3.2538
# Epoch 38/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.2716 - accuracy: 0.9038 - categorical_crossentropy: 0.2718 - val_loss: 3.1882 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.1882
# Epoch 39/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.2970 - accuracy: 0.8955 - categorical_crossentropy: 0.2968 - val_loss: 2.9965 - val_accuracy: 0.5000 - val_categorical_crossentropy: 2.9965
# Epoch 40/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.2909 - accuracy: 0.8974 - categorical_crossentropy: 0.2918 - val_loss: 3.0084 - val_accuracy: 0.4667 - val_categorical_crossentropy: 3.0084
# Epoch 41/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.2616 - accuracy: 0.9018 - categorical_crossentropy: 0.2605 - val_loss: 3.2113 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.2113
# Epoch 42/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.2541 - accuracy: 0.9094 - categorical_crossentropy: 0.2539 - val_loss: 3.0104 - val_accuracy: 0.5333 - val_categorical_crossentropy: 3.0104
# Epoch 43/100
# 154/154 [==============================] - 35s 224ms/step - loss: 0.2558 - accuracy: 0.9101 - categorical_crossentropy: 0.2558 - val_loss: 3.1129 - val_accuracy: 0.4667 - val_categorical_crossentropy: 3.1129
# Epoch 44/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.2543 - accuracy: 0.9151 - categorical_crossentropy: 0.2556 - val_loss: 3.2167 - val_accuracy: 0.4667 - val_categorical_crossentropy: 3.2167
# Epoch 45/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.2539 - accuracy: 0.9148 - categorical_crossentropy: 0.2485 - val_loss: 2.9474 - val_accuracy: 0.5000 - val_categorical_crossentropy: 2.9474
# Epoch 46/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.2360 - accuracy: 0.9188 - categorical_crossentropy: 0.2364 - val_loss: 3.2225 - val_accuracy: 0.4667 - val_categorical_crossentropy: 3.2225
# Epoch 47/100
# 154/154 [==============================] - 35s 225ms/step - loss: 0.2471 - accuracy: 0.9152 - categorical_crossentropy: 0.2471 - val_loss: 3.2675 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.2675
# Epoch 48/100
# 154/154 [==============================] - 34s 224ms/step - loss: 0.2506 - accuracy: 0.9182 - categorical_crossentropy: 0.2474 - val_loss: 3.1047 - val_accuracy: 0.4667 - val_categorical_crossentropy: 3.1047
# Epoch 49/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.2410 - accuracy: 0.9171 - categorical_crossentropy: 0.2415 - val_loss: 3.1038 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.1038
# Epoch 50/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.2333 - accuracy: 0.9210 - categorical_crossentropy: 0.2339 - val_loss: 3.2107 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.2107
# Epoch 51/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.2219 - accuracy: 0.9250 - categorical_crossentropy: 0.2229 - val_loss: 3.3560 - val_accuracy: 0.5333 - val_categorical_crossentropy: 3.3560
# Epoch 52/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.2104 - accuracy: 0.9297 - categorical_crossentropy: 0.2104 - val_loss: 3.3950 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.3950
# Epoch 53/100
# 154/154 [==============================] - 34s 220ms/step - loss: 0.2241 - accuracy: 0.9254 - categorical_crossentropy: 0.2211 - val_loss: 3.1555 - val_accuracy: 0.4000 - val_categorical_crossentropy: 3.1555
# Epoch 54/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.2110 - accuracy: 0.9286 - categorical_crossentropy: 0.2121 - val_loss: 3.2822 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.2822
# Epoch 55/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.1954 - accuracy: 0.9336 - categorical_crossentropy: 0.1954 - val_loss: 3.2064 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.2064
# Epoch 56/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1965 - accuracy: 0.9325 - categorical_crossentropy: 0.1950 - val_loss: 3.4531 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.4531
# Epoch 57/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.2155 - accuracy: 0.9283 - categorical_crossentropy: 0.2151 - val_loss: 3.2735 - val_accuracy: 0.5333 - val_categorical_crossentropy: 3.2735
# Epoch 58/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.2112 - accuracy: 0.9262 - categorical_crossentropy: 0.2119 - val_loss: 3.0807 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.0807
# Epoch 59/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.2001 - accuracy: 0.9344 - categorical_crossentropy: 0.2001 - val_loss: 3.3706 - val_accuracy: 0.5333 - val_categorical_crossentropy: 3.3706
# Epoch 60/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1836 - accuracy: 0.9391 - categorical_crossentropy: 0.1837 - val_loss: 3.3364 - val_accuracy: 0.4667 - val_categorical_crossentropy: 3.3364
# Epoch 61/100
# 154/154 [==============================] - 34s 224ms/step - loss: 0.1782 - accuracy: 0.9364 - categorical_crossentropy: 0.1790 - val_loss: 3.4687 - val_accuracy: 0.4000 - val_categorical_crossentropy: 3.4687
# Epoch 62/100
# 154/154 [==============================] - 34s 224ms/step - loss: 0.1930 - accuracy: 0.9382 - categorical_crossentropy: 0.1934 - val_loss: 3.6246 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.6246
# Epoch 63/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.1927 - accuracy: 0.9330 - categorical_crossentropy: 0.1920 - val_loss: 3.5486 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.5486
# Epoch 64/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.1919 - accuracy: 0.9375 - categorical_crossentropy: 0.1925 - val_loss: 3.2826 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.2826
# Epoch 65/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.1645 - accuracy: 0.9416 - categorical_crossentropy: 0.1652 - val_loss: 3.3327 - val_accuracy: 0.5333 - val_categorical_crossentropy: 3.3327
# Epoch 66/100
# 154/154 [==============================] - 35s 225ms/step - loss: 0.1790 - accuracy: 0.9386 - categorical_crossentropy: 0.1787 - val_loss: 3.3206 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.3206
# Epoch 67/100
# 154/154 [==============================] - 35s 225ms/step - loss: 0.1708 - accuracy: 0.9464 - categorical_crossentropy: 0.1708 - val_loss: 3.2100 - val_accuracy: 0.5333 - val_categorical_crossentropy: 3.2100
# Epoch 68/100
# 154/154 [==============================] - 34s 220ms/step - loss: 0.1764 - accuracy: 0.9409 - categorical_crossentropy: 0.1767 - val_loss: 3.6509 - val_accuracy: 0.4667 - val_categorical_crossentropy: 3.6509
# Epoch 69/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1773 - accuracy: 0.9401 - categorical_crossentropy: 0.1778 - val_loss: 3.4189 - val_accuracy: 0.5333 - val_categorical_crossentropy: 3.4189
# Epoch 70/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.1828 - accuracy: 0.9403 - categorical_crossentropy: 0.1828 - val_loss: 3.1365 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.1365
# Epoch 71/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1739 - accuracy: 0.9441 - categorical_crossentropy: 0.1748 - val_loss: 3.2819 - val_accuracy: 0.4000 - val_categorical_crossentropy: 3.2819
# Epoch 72/100
# 154/154 [==============================] - 34s 220ms/step - loss: 0.1735 - accuracy: 0.9433 - categorical_crossentropy: 0.1726 - val_loss: 3.6700 - val_accuracy: 0.4000 - val_categorical_crossentropy: 3.6700
# Epoch 73/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.1539 - accuracy: 0.9481 - categorical_crossentropy: 0.1539 - val_loss: 3.2407 - val_accuracy: 0.5333 - val_categorical_crossentropy: 3.2407
# Epoch 74/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1666 - accuracy: 0.9446 - categorical_crossentropy: 0.1653 - val_loss: 3.3426 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.3426
# Epoch 75/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.1646 - accuracy: 0.9434 - categorical_crossentropy: 0.1646 - val_loss: 3.4927 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.4927
# Epoch 76/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.1842 - accuracy: 0.9359 - categorical_crossentropy: 0.1846 - val_loss: 3.5291 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.5291
# Epoch 77/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.1692 - accuracy: 0.9454 - categorical_crossentropy: 0.1684 - val_loss: 3.1840 - val_accuracy: 0.5667 - val_categorical_crossentropy: 3.1840
# Epoch 78/100
# 154/154 [==============================] - 34s 224ms/step - loss: 0.1596 - accuracy: 0.9495 - categorical_crossentropy: 0.1596 - val_loss: 3.1464 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.1464
# Epoch 79/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1321 - accuracy: 0.9547 - categorical_crossentropy: 0.1333 - val_loss: 3.5704 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.5704
# Epoch 80/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.1679 - accuracy: 0.9461 - categorical_crossentropy: 0.1686 - val_loss: 3.5113 - val_accuracy: 0.3667 - val_categorical_crossentropy: 3.5113
# Epoch 81/100
# 154/154 [==============================] - 34s 223ms/step - loss: 0.1452 - accuracy: 0.9489 - categorical_crossentropy: 0.1460 - val_loss: 3.6128 - val_accuracy: 0.4000 - val_categorical_crossentropy: 3.6128
# Epoch 82/100
# 154/154 [==============================] - 35s 224ms/step - loss: 0.1386 - accuracy: 0.9527 - categorical_crossentropy: 0.1386 - val_loss: 3.6515 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.6515
# Epoch 83/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.1551 - accuracy: 0.9488 - categorical_crossentropy: 0.1510 - val_loss: 3.7309 - val_accuracy: 0.4667 - val_categorical_crossentropy: 3.7309
# Epoch 84/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.1539 - accuracy: 0.9479 - categorical_crossentropy: 0.1529 - val_loss: 3.7303 - val_accuracy: 0.5333 - val_categorical_crossentropy: 3.7303
# Epoch 85/100
# 154/154 [==============================] - 35s 225ms/step - loss: 0.1530 - accuracy: 0.9499 - categorical_crossentropy: 0.1530 - val_loss: 3.4828 - val_accuracy: 0.4667 - val_categorical_crossentropy: 3.4828
# Epoch 86/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1322 - accuracy: 0.9586 - categorical_crossentropy: 0.1324 - val_loss: 3.9000 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.9000
# Epoch 87/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1398 - accuracy: 0.9510 - categorical_crossentropy: 0.1406 - val_loss: 3.7249 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.7249
# Epoch 88/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1416 - accuracy: 0.9492 - categorical_crossentropy: 0.1423 - val_loss: 3.6187 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.6187
# Epoch 89/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.1351 - accuracy: 0.9574 - categorical_crossentropy: 0.1351 - val_loss: 3.7585 - val_accuracy: 0.3667 - val_categorical_crossentropy: 3.7585
# Epoch 90/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1394 - accuracy: 0.9563 - categorical_crossentropy: 0.1377 - val_loss: 3.7039 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.7039
# Epoch 91/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1360 - accuracy: 0.9544 - categorical_crossentropy: 0.1367 - val_loss: 3.4817 - val_accuracy: 0.5333 - val_categorical_crossentropy: 3.4817
# Epoch 92/100
# 154/154 [==============================] - 34s 220ms/step - loss: 0.1205 - accuracy: 0.9591 - categorical_crossentropy: 0.1211 - val_loss: 3.4098 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.4098
# Epoch 93/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1300 - accuracy: 0.9582 - categorical_crossentropy: 0.1295 - val_loss: 3.4427 - val_accuracy: 0.4000 - val_categorical_crossentropy: 3.4427
# Epoch 94/100
# 154/154 [==============================] - 34s 222ms/step - loss: 0.1474 - accuracy: 0.9525 - categorical_crossentropy: 0.1443 - val_loss: 3.7500 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.7500
# Epoch 95/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1411 - accuracy: 0.9555 - categorical_crossentropy: 0.1416 - val_loss: 3.3225 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.3225
# Epoch 96/100
# 154/154 [==============================] - 34s 220ms/step - loss: 0.1373 - accuracy: 0.9573 - categorical_crossentropy: 0.1381 - val_loss: 3.2963 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.2963
# Epoch 97/100
# 154/154 [==============================] - 34s 221ms/step - loss: 0.1281 - accuracy: 0.9582 - categorical_crossentropy: 0.1274 - val_loss: 3.8817 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.8817
# Epoch 98/100
# 154/154 [==============================] - 34s 220ms/step - loss: 0.1323 - accuracy: 0.9565 - categorical_crossentropy: 0.1311 - val_loss: 3.8988 - val_accuracy: 0.3667 - val_categorical_crossentropy: 3.8988
# Epoch 99/100
# 154/154 [==============================] - 34s 220ms/step - loss: 0.1371 - accuracy: 0.9577 - categorical_crossentropy: 0.1377 - val_loss: 3.6809 - val_accuracy: 0.5000 - val_categorical_crossentropy: 3.6809
# Epoch 100/100
# 154/154 [==============================] - 34s 219ms/step - loss: 0.1109 - accuracy: 0.9622 - categorical_crossentropy: 0.1120 - val_loss: 3.9707 - val_accuracy: 0.4333 - val_categorical_crossentropy: 3.9707

# %%
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.figure()


# Desired output. Charts with training and validation metrics. No crash :)

# %%
# Here's a codeblock just for fun. You should be able to upload an image here 
# and have it classified without crashing
import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

reverseLabelLookup = {value:key for key,value in train_generator.class_indices.items()}

for fn in uploaded.keys():
 
  # predicting images
  print("Filename :",fn)
  path = '/content/' + fn
  img = image.load_img(path, target_size=(200, 200, 3))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)

  plt.imshow(img)

  print("Predicted Movie Genre is ",reverseLabelLookup[np.argmax(classes)])
  print("Actual Movie Genre is ",movieListDatabase[movieListDatabase["FileNames"]==fn]["Genres"].to_string(index=False))

  print(classes)
# Out:
#      <input type="file" id="files-6529513e-82fc-479a-b417-8b8a91a8f825" name="files[]" multiple disabled />
#      <output id="result-6529513e-82fc-479a-b417-8b8a91a8f825">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Incredibles2.jpeg to Incredibles2 (1).jpeg
# Filename : Incredibles2.jpeg
# Predicted Movie Genre is  Action
# Actual Movie Genre is  Series([], )
# [[1. 0. 0. 0. 0. 0. 0. 0. 0.]]
