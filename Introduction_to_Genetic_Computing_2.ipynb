# %% [markdown]
# <a href="https://colab.research.google.com/github/datasigntist/deeplearning/blob/master/Introduction_to_Genetic_Computing_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction to Genetic Computing-2**
#
# Author : Vishwanathan Raman
#
# EmailId : datasigntist@gmail.com
#
# Description :
#
# This notebook illustrates the concept of Genetic Computing through an example (of generating a text "to be or not to be") based approach.
#
# The genetic algorithm is a method for solving both constrained and unconstrained optimization problems that is based on natural selection, the process that drives biological evolution. Ref : [Genetic Computing](https://in.mathworks.com/help/gads/what-is-the-genetic-algorithm.html)
#
# The objective is to be able to generate the text "to be or not to be". This can be attempted using a conventional probabilistic approach but doing so will take years to get to the solution of the problem.
#
# In the context of Genetic Computing the following are the key elements
#
# *   Defining a solution space by generating an initial population
# *   The solution space consists of potential configurations
# *   Defining a fitness function to evaluate the solutions in the solution space
# *   Once the initial population and fitness score is done, new configurations are created in the solution space through crossover and mutation.
# *  The following figure shows how the crossover and mutation works. The figure has been sourced from [Artificial Intelligence 3e: A Modern Approach Paperback](https://www.amazon.in/Artificial-Intelligence-3e-Modern-Approach/dp/9332543518/ref=sr_1_1_sspa?crid=3R7D136Z3TTP9&keywords=artificial+intelligence+a+modern+approach+3rd+edition&qid=1575521071&sprefix=Artificial+Inte%2Caps%2C292&sr=8-1-spons&psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUExTlUwMFlSVTdXOUxRJmVuY3J5cHRlZElkPUEwMzE2NDUxM042RkFXUUdMNFhGTiZlbmNyeXB0ZWRBZElkPUEwMTUzMjM0MjNQTkU4R0RIS01aNSZ3aWRnZXROYW1lPXNwX2F0ZiZhY3Rpb249Y2xpY2tSZWRpcmVjdCZkb05vdExvZ0NsaWNrPXRydWU=)
#
# ![alt text](https://github.com/datasigntist/imagesforNotebook/raw/master/Genetic%20Computing.png)
#
# References:
#
# A primer Introduction to Evolutionary Computing and Genetic Algorithms
#
# https://www.youtube.com/watch?v=9zfeTw-uFCw&list=PLRqwX-V7Uu6bJM3VgzjNV5YxVxUwzALHV

# %%
import random
import numpy as np
from numpy.random import choice
import pandas as pd

# %%
mutationRate = 0.01
totalPopulation = 150
crossOver = 0.5

# %%
target = "winner takes it all"
alpha_list = [chr(x) for x in range(ord('a'), ord('z') + 1)] 
alpha_list.append(' ')

# %%
populationData = []
fitnessData = []
secure_random = random.SystemRandom()
for outloop in range(totalPopulation):
  randomData = []
  fitnessScore = 0
  for inloop in range(len(target)):
    selectedData = secure_random.choice(alpha_list)
    if (selectedData == target[inloop]):
      fitnessScore = fitnessScore + 1
    randomData.append(selectedData)
  populationData.append(randomData)
  fitnessData.append(fitnessScore)
probabilityDist = []
for outloop in range(totalPopulation):
  probabilityDist.append(fitnessData[outloop]/len(target))
probDataFrame = pd.DataFrame({'String':populationData,'FitnessScore':fitnessData,'Probability':probabilityDist})
probDataFrame = probDataFrame.sort_values(['Probability'],ascending=False)
probDataFrame = probDataFrame.reset_index(drop=True)

# %% [markdown]
# Glimpse of the solution space that has been generated as part of the initial population

# %%
probDataFrame.head()
# Out:
#                                               String  FitnessScore  Probability
# 0  [o, x, e, l, u, i, u, t, c, j, f, s,  , i, c, ...             5     0.263158
# 1  [i, s, n, i, b, o, l, t, a, z, v, t,  , y, m, ...             5     0.263158
# 2  [p, j, n, f, v, m, n, i, a, p, r, s, s, u, t, ...             4     0.210526
# 3  [w, g, h, r, q, r, o, r, x, c, k, s,  , h, f, ...             4     0.210526
# 4  [w, y, c, c, x, n,  ,  , o, k, t, k, b, k, t, ...             4     0.210526

# %%
def maxProb(probabilityDist):
  probabilityList = [f for f in set(probabilityDist)]
  return (probabilityList[len(probabilityList)-2])

# %%
def getFitnessScore(data):
    data = ''.join([elem for elem in data])
    fitnessScore = 0
    for inloop in range(len(target)):
      if (data[inloop] == target[inloop]):
        fitnessScore = fitnessScore + 1
    return fitnessScore

# %%
def viewElement(data):
    data = ''.join([elem for elem in data])
    return data

# %%
crossOverPoint = int(crossOver*len(target))
generationCount = 1000
for loop in range(generationCount):
  draw=[]
  draw.append(probDataFrame[0:1]["String"].values[0])
  draw.append(probDataFrame[1:2]["String"].values[0])
  #print('Fitness Scores of Parents ',getFitnessScore(draw[0]),getFitnessScore(draw[1]))
  if (getFitnessScore(draw[0])==len(target) | getFitnessScore(draw[1])==len(target)):
    print(viewElement(draw[0]),' ',viewElement(draw[1]))
    break
  child1 = draw[0][0:crossOverPoint]+draw[1][crossOverPoint:]
  child2 = draw[1][0:crossOverPoint]+draw[0][crossOverPoint:]
  child1[random.randint(0,len(target)-1)] = secure_random.choice(alpha_list)
  child2[random.randint(0,len(target)-1)] = secure_random.choice(alpha_list)
  populationData.append(child1)
  populationData.append(child2)
  fitnessData = []
  totalPopulation = len(populationData)
  for outloop in range(totalPopulation):
    fitnessScore = getFitnessScore(populationData[outloop])
    fitnessData.append(fitnessScore)
  probabilityDist = []
  for outloop in range(totalPopulation):
    probabilityDist.append(fitnessData[outloop]/sum(fitnessData))
  probDataFrame = pd.DataFrame({'String':populationData,'FitnessScore':fitnessData,'Probability':probabilityDist})
  probDataFrame = probDataFrame.sort_values(['Probability'],ascending=False)
  probDataFrame = probDataFrame.reset_index(drop=True)
  print('Generation ',loop,' ',' Average Fitness Score ',probDataFrame["FitnessScore"].mean(),' ', ''.join(elem for elem in child1),' ',getFitnessScore(child1),''.join(elem for elem in child2),getFitnessScore(child2))
  #print('Generation ',loop,' ',' Average Fitness Score ',probDataFrame["FitnessScore"].mean())
# Out:
# Generation  0    Average Fitness Score  0.7395626242544732   iiinyw brdfstfsyblf   5 zivuensthxvmoftbelj 5
# Generation  1    Average Fitness Score  0.7437934458788481   ziv ensthuvmoftbelj   5 ciinyw brxvmoftbelj 5
# Generation  2    Average Fitness Score  0.748015873015873   ciinyw bruxmoftbelj   5 ziv ensthxvmaftbelj 5
# Generation  3    Average Fitness Score  0.7522299306243806   ziv ensthxvmoftkelj   5 zivuensthxvcaftbelj 5
# Generation  4    Average Fitness Score  0.7564356435643564   zivuensthuvmoftcelj   5 ziv ensthxvcaftbelj 5
# Generation  5    Average Fitness Score  0.7601384767556875   ziv ensthxvvoftbelj   5 ciinywpbrxvcaftbelj 4
# Generation  6    Average Fitness Score  0.7643280632411067   iiinyw prxvmaftbelj   5 ziv ensthuvmoftbllj 5
# Generation  7    Average Fitness Score  0.7680157946692991   ziv ensthxvmoftke j   4 ziv ensthulmoftbllj 5
# Generation  8    Average Fitness Score  0.7712031558185405   ziv ensthxvcafubelj   4 zivuensthulmoftblwj 4
# Generation  9    Average Fitness Score  0.7748768472906404   zif ensthxvcaftbelj   5 zuv ensthxvmaftbelj 4
# Generation  10    Average Fitness Score  0.7790354330708661   zivuensthxvcaftbeld   5 ziv ensthxvcaftjelj 5
# Generation  11    Average Fitness Score  0.7822025565388397   ziv enshhxvvoftbelj   4 zrv ensthxvcaftjelj 4
# Generation  12    Average Fitness Score  0.7863457760314342   ziv ensthxvmaftcelj   5 iiinyt prxvcaftbelj 5
# Generation  13    Average Fitness Score  0.7899901864573111   iiinytaprxvmaftbelj   4 iiinsw prxvcaftbelj 5
# Generation  14    Average Fitness Score  0.7936274509803921   irinsw pruvmoftbllj   4 ziv ensthxgcaftbelj 5
# Generation  15    Average Fitness Score  0.797747306562194   ziv enlthuvmoftbllj   5 ziv ensthxncaftbelj 5
# Generation  16    Average Fitness Score  0.8013698630136986   zav ensthxvcaftbelj   4 zivuenstnxncaftbelj 5
# Generation  17    Average Fitness Score  0.8059628543499511   zivuenstnulmodtbllj   5 ziv ensthxncaitbelj 6
# Generation  18    Average Fitness Score  0.810546875   ziv ensthhvcaftbelj   5 zivuenothxncaitbelj 6
# Generation  19    Average Fitness Score  0.8156097560975609   zivuenothxncaitbglj   6 ziv ensthxncaitbelv 6
# Generation  20    Average Fitness Score  0.8206627680311891   ziv ensthxocaitbglj   6 zivueaothxncaitbelv 6
# Generation  21    Average Fitness Score  0.8257059396299903   zivueaothxofaitbglj   6 ziv ensthxnwaitbelv 6
# Generation  22    Average Fitness Score  0.830739299610895   ziv ensthxlfaitbglj   6 zivueaothxnwaitaelv 6
# Generation  23    Average Fitness Score  0.8352769679300291   zivueaothxdcaitbglj   6 ziv ensthxnwaimaelv 5
# Generation  24    Average Fitness Score  0.8398058252427184   zivuenothxocaitbglj   6 zivueaochxncaitbglj 5
# Generation  25    Average Fitness Score  0.8448108632395732   ziv ensthxnwaitbelv   6 ziv ensthxncbitbelj 6
# Generation  26    Average Fitness Score  0.8498062015503876   ziv ensthxnwaitbelv   6 ziv enstixncbitbelj 6
# Generation  27    Average Fitness Score  0.8547918683446273   ziv enstoxlfaitbglj   6 ziv ensthwncbitbelj 6
# Generation  28    Average Fitness Score  0.8588007736943907   ziv ensthxnwaiqaelv   5 znvueaothwncbitbelj 5
# Generation  29    Average Fitness Score  0.863768115942029   ziv encthxdcaitbglj   6 zivueauthxocaitbglj 6
# Generation  30    Average Fitness Score  0.8687258687258688   zivueawthxocaitbglj   6 zivuenothxoczitbglj 6
# Generation  31    Average Fitness Score  0.8736740597878495   zivueeothxocaitbglj   6 zivuenothxorzitbglj 6
# Generation  32    Average Fitness Score  0.878131021194605   zsvuenothxnwaitbelv   5 ziv ensthxorzitbjlj 6
# Generation  33    Average Fitness Score  0.8820981713185756   ziv ensthxncbitbepj   5 zmv ensthxorzitbjlj 5
# Generation  34    Average Fitness Score  0.8870192307692307   zivueaothyncbitbelj   6 ziv enstibnwaitaelv 6
# Generation  35    Average Fitness Score  0.8919308357348703   ziv enstixncbitbelj   6 ziv enstbbnwaitaelv 6
# Generation  36    Average Fitness Score  0.8968330134357005   zivoenstbwncbitbelj   6 zib ensthbnwaitaelv 6
# Generation  37    Average Fitness Score  0.9012464046021093   zib unsthxdcaitbglj   5 zivueaotebnwaitaelv 6
# Generation  38    Average Fitness Score  0.9056513409961686   zivueaotewncbitberj   5  iv ensthbnwaitaelv 6
# Generation  39    Average Fitness Score  0.9105263157894737    iv ensthxnwaitcelv   6 zimueaothbnwaitaelv 6
# Generation  40    Average Fitness Score  0.9153919694072657   zimueaothxocaitzglj   6 zivueauthbnwaithelv 6
# Generation  41    Average Fitness Score  0.9197707736389685   zivueauthxnwaitaeuv   5 zivueaothbnwaithelu 6
# Generation  42    Average Fitness Score  0.9241412213740458   zivueaothxoczityglj   6 zivuenojhbnwaithelu 5
# Generation  43    Average Fitness Score  0.9285033365109628   ziv ensthxnwaityelv   6 ziv enshhxncaitbelv 5
# Generation  44    Average Fitness Score  0.9328571428571428   ziv encthxocaiwbglj   5 zivuenothddcaitbglj 6
# Generation  45    Average Fitness Score  0.9376784015223597   zivuenothxswaitbelv   6 ziv enstlddcaitbglj 6
# Generation  46    Average Fitness Score  0.9424904942965779   ziv enstlxncvitbelj   6 ziv enlthddcaitbglj 6
# Generation  47    Average Fitness Score  0.9468186134852802   ziv enltuyncbitbelj   6 zivueaoahddcaitbglj 5
# Generation  48    Average Fitness Score  0.9511385199240987   ziv ensdbxocaitbglj   5 zivueawthfnwaitaelv 6
# Generation  49    Average Fitness Score  0.9559241706161138   zivueawthxncbitxelj   6 ziv enstifnwaitaelv 6
# Generation  50    Average Fitness Score  0.9602272727272727   ziv enstiwnceitbelj   6 zivoensgbfnwaitaelv 5
# Generation  51    Average Fitness Score  0.9645222327341533   zivuenothbnwaltaelv   5 zib ensthxzcaitbglj 6
# Generation  52    Average Fitness Score  0.969281663516068   zib ensthwn bitbelj   6 ziv envthxzcaitbglj 6
# Generation  53    Average Fitness Score  0.9740321057601511   ziv envthbnwaitaelg   6 zivueaotextcaitbglj 6
# Generation  54    Average Fitness Score  0.9783018867924528   zivueaotexrcaitbelj   6 ziv mnsthxtcaitbglj 5
# Generation  55    Average Fitness Score  0.9830348727615457   ziv ensthxdwaitbglj   6 ziv enctuxlfaitbglj 6
# Generation  56    Average Fitness Score  0.9868173258003766   ziv enctuyncbicbelj   5 zivueaonhxlfaitbglj 5
# Generation  57    Average Fitness Score  0.9915333960489181   zivueaothbnwaiwhelv   5 zivueautaxdcaitbglj 7
# Generation  58    Average Fitness Score  0.9967105263157895   ziiueautaxncaitbelj   7 zikuenothxdcaitbglj 6
# Generation  59    Average Fitness Score  1.0023474178403755   ziiueautaxdmaitbglj   7 zivuefutaxncaitbelj 7
# Generation  60    Average Fitness Score  1.0075046904315197   zvvuefutaxdmaitbglj   6 ziwueautaxncaitbelj 7
# Generation  61    Average Fitness Score  1.012652296157451   ziwueauthxncaitbelj   6 zivuefutaxjcaitbelj 7
# Generation  62    Average Fitness Score  1.0182584269662922   zivuefutaxncaitbjlj   7 ziwueautaxjcaitbulj 7
# Generation  63    Average Fitness Score  1.0233863423760523   ziwueautaxncaitbtlj   7 ziwueautaxjcautbulj 6
# Generation  64    Average Fitness Score  1.0285046728971963   zxvuefutaxdcaitbglj   6 zivueautaxncaitbylj 7
# Generation  65    Average Fitness Score  1.0340802987861812   zivueautaxjcuitbelj   7 zivuefutaxncxitbylj 7
# Generation  66    Average Fitness Score  1.039179104477612   zivuefutaxjtuitbelj   7 zivueautxxncxitbylj 6
# Generation  67    Average Fitness Score  1.044268406337372   ziiueaulaxncaitbtlj   6 ziwueautaxdpaitbglj 7
# Generation  68    Average Fitness Score  1.0488826815642458   ziwueautaxncaitbtfj   6 ziwueautaxdpadtbglj 6
# Generation  69    Average Fitness Score  1.0539534883720931   ziwuebutaxncaitbylj   7 zivueautaxncaigbelj 6
# Generation  70    Average Fitness Score  1.058550185873606   ziiueautuxjcaitbelj   6 zvvuefutaxncaitbelj 6
# Generation  71    Average Fitness Score  1.063602599814299   zivuefut xncxitbylj   6 zivuequtaxncaitbjlj 7
# Generation  72    Average Fitness Score  1.0686456400742115   zivuequtaxncnitbylj   7 zivuefutcxncaitbjlj 6
# Generation  73    Average Fitness Score  1.0741427247451343   ziqueautaxncaitbelj   7 ziiqeautaxdcaitbglj 7
# Generation  74    Average Fitness Score  1.0796296296296297   ziiqeoutaxjtuitbelj   7 zivuefutaxdcaitbgls 7
# Generation  75    Average Fitness Score  1.0851063829787233   zivuefutaxdpaitbglj   7 ziwueamtaxdcaitbgls 7
# Generation  76    Average Fitness Score  1.0901109057301295   ziwreamtaxdpaitbglj   7 ziwueautaxdcaitbgvs 6
# Generation  77    Average Fitness Score  1.0951061865189289   zivuefutkxncaitbylj   6 zijuebutaxjtuitbelj 7
# Generation  78    Average Fitness Score  1.1000922509225093   zijuwbutaxncaitbylj   6 ziwuebutahjtuitbelj 7
# Generation  79    Average Fitness Score  1.1055299539170507   ziwuebutaxncaityjlj   7 zivlequtahjtuitbelj 7
# Generation  80    Average Fitness Score  1.1104972375690607   zivlequtaxdcaitbjlj   7 zivuequtuhjtuitbelj 6
# Generation  81    Average Fitness Score  1.1159153633854646   ziwueautaencaitbelj   7 zisueautaxjcaitbulj 7
# Generation  82    Average Fitness Score  1.1213235294117647   ziszeautaxncaitbelj   7 ziqueautaxjcgitbulj 7
# Generation  83    Average Fitness Score  1.1267217630853994   ziqueautaxncaitbtlc   7 ziwuesutaxjcgitbulj 7
# Generation  84    Average Fitness Score  1.1311926605504588   ziwuesuraxjtuitbelj   6 ziiqeoutaxjcgivbulj 6
# Generation  85    Average Fitness Score  1.1365719523373052   zivuefutaxdcaitbglj   7 zivueautaxncaitwjlj 7
# Generation  86    Average Fitness Score  1.141025641025641   zivueautixdpaitbglj   6 zivuefuoaxncaitwjlj 6
# Generation  87    Average Fitness Score  1.1459286367795058   zhqueautaxjtuitbelj   6 zijuebctaxncaitbelj 7
# Generation  88    Average Fitness Score  1.1508226691042047   rijuebctaxdpaitbglj   7 ziwreamuaxncaitbelj 6
# Generation  89    Average Fitness Score  1.1552511415525115   ziwueamtaxdmaiqbglj   6 ziiujautaxdcaitbgls 6
# Generation  90    Average Fitness Score  1.1605839416058394   zivuefutaxncaityjlj   7 ziwuebutaxotuitbelj 7
# Generation  91    Average Fitness Score  1.1654512306289881   ziwuebutaxncaitbelj   7 ziqudautaxotuitbelj 6
# Generation  92    Average Fitness Score  1.1703096539162112   zijuebitahjtuitbelj   7 zqvlequtaxjtuitbelj 6
# Generation  93    Average Fitness Score  1.175614194722475   zfvuefutaxdpaitbglj   6 ziwueautaxjcaitbalj 8
# Generation  94    Average Fitness Score  1.180909090909091   ziwueautaxfcaitbylj   7 ziwuebutaxjcaitbrlj 7
# Generation  95    Average Fitness Score  1.1857402361489555   zfwueautaxjcaitbrlj   6 ziwuebufaxjcaitbalj 7
# Generation  96    Average Fitness Score  1.190562613430127   ziwuvautaxjcaitbalj   7 zbwuebufaxjcaitbalj 6
# Generation  97    Average Fitness Score  1.1953762466001814   ziwunautaxdpaitbglj   6 ziwreamyaxjcaitbalj 7
# Generation  98    Average Fitness Score  1.2006340579710144   ziwueautaxjcaitbaij   7 ziwreamyaxjcaitbalk 7
# Generation  99    Average Fitness Score  1.2063348416289592   ziwueautaxdcaitbalk   8 zisreamyaxjcaitbalj 7
# Generation  100    Average Fitness Score  1.2120253164556962   ziwueautaxjcaitbalj   8 zrwueautaxdcaitbalk 7
# Generation  101    Average Fitness Score  1.217705510388437   ziwueaukaxjcaitbalj   7 ziwueuutaxjcaitbalj 8
# Generation  102    Average Fitness Score  1.223375451263538   ziwueuutaxjcagtbalj   7 zizueautaxjcaitbalj 8
# Generation  103    Average Fitness Score  1.2290351668169521   zizueautaxjcaitbtlj   7 ziwueuutaxjxaitbalj 8
# Generation  104    Average Fitness Score  1.2346846846846846   ziwueuxtaxjcaitbalj   8 ziwueuuaaxjxaitbalj 7
# Generation  105    Average Fitness Score  1.2403240324032403   ziwueautaxjcaktbalj   7 ziwueuxtaxjcmitbalj 8
# Generation  106    Average Fitness Score  1.245503597122302   ziwueuxmaxjcaitbalj   7 zizuwautaxjcmitbalj 7
# Generation  107    Average Fitness Score  1.2511230907457322   ziwueautaxjcaitbplj   7 ziwueuutaxdcaitkalk 8
# Generation  108    Average Fitness Score  1.257181328545781   zizueuutaxjcaitbalj   8 ziwueuxtamdcaitkalk 8
# Generation  109    Average Fitness Score  1.2632286995515696   ziwaeuxtaxjcaitbalj   8 zizuebutamdcaitkalk 8
# Generation  110    Average Fitness Score  1.2688172043010753   zizuebdtaxjcmitbalj   8 zwwueuxtamdcaitkalk 7
# Generation  111    Average Fitness Score  1.274395702775291   siwueuxtaxjxaitbalj   8 ziwueuueaxjcmitbalj 7
# Generation  112    Average Fitness Score  1.279964221824687   ziwueautaxdcaittalk   8 ziwueuutaxdcaitbslk 7
# Generation  113    Average Fitness Score  1.2850759606791777   ziwueuutamdcavtkalk   7 ziwueuxtaxjcaifbalj 7
# Generation  114    Average Fitness Score  1.2910714285714286   ziwueuxtaxjoaitbalj   8 ziwaeuxtaxocmitbalj 8
# Generation  115    Average Fitness Score  1.297056199821588   ziwaeuxtaxjctitbalj   8 ziwaeuxtaxocmitbalj 8
# Generation  116    Average Fitness Score  1.302584670231729   ziwaeuxtamdcnitkalk   8 zizuebutjxocmitbalj 7
# Generation  117    Average Fitness Score  1.3085485307212823   zizueautaxjxaitbalr   8 siwueuxtaxjccitbalj 8
# Generation  118    Average Fitness Score  1.3145017793594307   sixueuxtaxjxaitbalj   8 kiwueuxtaxjccitbalj 8
# Generation  119    Average Fitness Score  1.3204444444444445   kiwuezxtaxjxaitbalj   8 siwueuxtaxjccitbalj 8
# Generation  120    Average Fitness Score  1.3259325044404973   siwueuxtaxdcaittank   7 zifueautaxjccitbalj 8
# Generation  121    Average Fitness Score  1.331410825199645   zifueautaxdcaitpalk   8 zvwueautaxjccitbalj 7
# Generation  122    Average Fitness Score  1.337322695035461   ziwuehxtaxocmitbalj   8 ziwaeuxtayjoaitbalj 8
# Generation  123    Average Fitness Score  1.3432240921169176   zvwaeuxtaxocmitbalj   7 ziwaeuxtayjsaitbalj 9
# Generation  124    Average Fitness Score  1.3491150442477877   ziwaeuqtaxocmitbalj   8 ziwaeuxtayjsaitbblj 8
# Generation  125    Average Fitness Score  1.3554376657824934   ziwaenxtayjsaitbblj   8 ziwxeuxtayjsaitbalj 9
# Generation  126    Average Fitness Score  1.3617491166077738   zidxeuxtayjsaitbalj   9 ziwaeuxlayjsaitbalj 8
# Generation  127    Average Fitness Score  1.3684907325684024   zidxeuxtaydsaitbalj   9 ziwxeuxtayjsgitbalj 9
# Generation  128    Average Fitness Score  1.375220458553792   ziwxeuxtayfsaitbalj   9 zidxebxtayjsgitbalj 9
# Generation  129    Average Fitness Score  1.381057268722467   ztdxebxtayfsaitbalj   8 ziwxluxtayjsgitbalj 8
# Generation  130    Average Fitness Score  1.3877640845070423   zidxeqxtayjsgitbalj   9 zidxebxtaxjsaitbalj 9
# Generation  131    Average Fitness Score  1.393579595426561   zidxjbxtayfsaitbalj   8 zywxeuxtaxjsaitbalj 8
# Generation  132    Average Fitness Score  1.399384885764499   zidxuuxtayjsaitbalj   8 ziwxeuxdaydsaitbalj 8
# Generation  133    Average Fitness Score  1.4060579455662863   ziwceuxtayjsgitbalj   9 zidxebctayfsaitbalj 9
# Generation  134    Average Fitness Score  1.412280701754386   zidxibctayjsgitbalj   8 zidreqxtayfsaitbalj 9
# Generation  135    Average Fitness Score  1.4184925503943908   zidrenxtaxjsaitbalj   9 zidxebxtayfgaitbalj 8
# Generation  136    Average Fitness Score  1.4242556917688267   zidxeuxtayjfgitbalj   8 zidxeqxcaydsaitbalj 8
# Generation  137    Average Fitness Score  1.4304461942257218   tiwxeuxtayjsaitbalj   9 ziwxeuxtoyjsgitbalj 8
# Generation  138    Average Fitness Score  1.4361888111888113   ziwxeuxtdyjsaitbalj   8 ziwaeuxtayfsaitbulj 8
# Generation  139    Average Fitness Score  1.44235807860262   zidxebxtaxjsaitbawj   8 zidxebxtayjsritbalj 9
# Generation  140    Average Fitness Score  1.4485165794066317   zidxeaxtayfsaitbalj   9 zidreqxtayjsrilbalj 8
# Generation  141    Average Fitness Score  1.4542284219703574   ziwxeuxnayjsgitbalj   8 zidxeqxtayfsaiebalj 8
# Generation  142    Average Fitness Score  1.4603658536585367   zidxvbxtaxjsaitbalj   8 zidrenztaxjsaitbalj 9
# Generation  143    Average Fitness Score  1.4669277632724107   ziwrenztaxjsaitbalj   9 zidzenxtaxjsaitbalj 9
# Generation  144    Average Fitness Score  1.472608695652174   zidzenxtaydsaitbajj   8 zidxeuxtaxjsaitbulj 8
# Generation  145    Average Fitness Score  1.47871416159861   ziwxeuxtayjsjitbalj   9 zidxebxtayjsaitbblj 8
# Generation  146    Average Fitness Score  1.4852430555555556   ziwaeuxtayjsritbvlj   8 zidxeb tayjsaitbalj 10
# Generation  147    Average Fitness Score  1.4917606244579358   zidxebrtayjsritbalj   9 zidxefxtayjsaitbalj 9
# Generation  148    Average Fitness Score  1.498266897746967   zidxfb tayjsaitbalj   9 zidxefxtayjsbitbalj 9
# Generation  149    Average Fitness Score  1.5051948051948052   zidxew tayjsbitbalj   10 zidxefxtayjsaitlalj 9
# Generation  150    Average Fitness Score  1.5121107266435987   zidxec tayjsaitbalj   10 zbdxeb tayjsbitbalj 9
# Generation  151    Average Fitness Score  1.5185825410544511   zidxeb tayjsaibbalj   9 zidxec tayjsaitbblj 9
# Generation  152    Average Fitness Score  1.525474956822107   uidxeb tayjsaitbalj   10 zidxdc tayjsaitbalj 9
# Generation  153    Average Fitness Score  1.5319240724762726   uidxqb tayjsaitbalj   9 zidxec tayjsaitbayj 9
# Generation  154    Average Fitness Score  1.5392241379310345   uidxeb taynsaitbalj   10 ziuxec tayjsaitbalj 10
# Generation  155    Average Fitness Score  1.5465116279069768   ziuxec tajnsaitbalj   10 uipxeb tayjsaitbalj 10
# Generation  156    Average Fitness Score  1.5537865748709123   uipxeb tajasaitbalj   10 ziuoec tayjsaitbalj 10
# Generation  157    Average Fitness Score  1.5606190885640585   ziucec taynsaitbalj   10 uidxeb tayjsaitbhlj 9
# Generation  158    Average Fitness Score  1.5674398625429553   ziucec taymsaitbalj   10 ziuoec taynsadtbalj 9
# Generation  159    Average Fitness Score  1.5742489270386266   uidxeb cayjsaitbalj   9 uipxec taynsaitbalj 10
# Generation  160    Average Fitness Score  1.58147512864494   uipxec tajasaitbaln   10 uipxel taynsaitbalj 10
# Generation  161    Average Fitness Score  1.5878320479862897   uipxel xajasaitbalj   9 uipxeb taynfaitbalj 9
# Generation  162    Average Fitness Score  1.5946061643835616   ziuoed tayjsbitbalj   10 zidxew kayjsaitbalj 9
# Generation  163    Average Fitness Score  1.6013686911890506   cidxeb tayjsbitbalj   10 zidxew baynsaitbalj 9
# Generation  164    Average Fitness Score  1.6081196581196582   ziuxec tabmsaitbalj   10 ziucec tayjsaitbnlj 9
# Generation  165    Average Fitness Score  1.6157130657557643   zidxeb tayrsaitbalj   10 ziucec tayesaitbalj 11
# Generation  166    Average Fitness Score  1.6224402730375427   ziucec tayniaitbalj   9 uipxec tayegaitbalj 10
# Generation  167    Average Fitness Score  1.6295822676896845   ziuclc tayegaitbalj   9 uiptec tayesaitbalj 11
# Generation  168    Average Fitness Score  1.637563884156729   uiptec tayesaitbalj   11 ziucec tayeseitbalj 11
# Generation  169    Average Fitness Score  1.6451063829787234   ziucec tayesaitcalj   11 uiptecbtayeseitbalj 10
# Generation  170    Average Fitness Score  1.653061224489796   ziucec tayeseitdalj   11 ziucec tayesaitcalj 11
# Generation  171    Average Fitness Score  1.6605777400169923   ziucec tayeseitdwlj   10 ziucec tajesaitcalj 11
# Generation  172    Average Fitness Score  1.6676570458404074   ziucecrtayesaitbalj   10 ziucec tajesaitcamj 10
# Generation  173    Average Fitness Score  1.6755725190839694   uiptec tajesaitcalj   11 ziucec tayesaitbalj 11
# Generation  174    Average Fitness Score  1.6830508474576271   ziwcec tayesaitcalj   11 ziucecmtayesaitbalj 10
# Generation  175    Average Fitness Score  1.690939881456393   ziucec tawesaitcalj   11 ziocec tayeseitbalj 11
# Generation  176    Average Fitness Score  1.6983925549915397   ziocew tayesaitcalj   11 ziucec taynseitbalj 10
# Generation  177    Average Fitness Score  1.705832628909552   zikcec tayesaitcalj   11 ziocewqtayesaitbalj 10
# Generation  178    Average Fitness Score  1.712837837837838   ziucec tayesainbalj   10 ziucec tayeseitdapj 10
# Generation  179    Average Fitness Score  1.720253164556962   ziucek tayesaitcalj   11 ziwchc tayesaitbalj 10
# Generation  180    Average Fitness Score  1.7280775716694772   ziucec tajesaitcalj   11 ziucec taaeseitbalj 11
# Generation  181    Average Fitness Score  1.7354675652906486   ziucec tayesaitcvlj   10 ziucec taaeseitzalj 11
# Generation  182    Average Fitness Score  1.7428451178451179   zsucec tayeseitbalj   10 ziocec taaeseittalj 11
# Generation  183    Average Fitness Score  1.7506307821698908   ziocec tayesaitcall   12 ziocew taaeseittplj 10
# Generation  184    Average Fitness Score  1.757983193277311   ziocec tayesaltcalj   10 zpwcec tayesaitcall 11
# Generation  185    Average Fitness Score  1.765743073047859   jiocec tayesaitcall   12 zpwcec tayesaltcall 10
# Generation  186    Average Fitness Score  1.773489932885906   jiocec tlyesaitcall   11 ziocec tayesajtcall 11
# Generation  187    Average Fitness Score  1.782062028499581   jiocec tayesaitcall   12 ziocee tayesaitcall 12
# Generation  188    Average Fitness Score  1.7906197654941374   ziosee tayesaitcall   12 ziocec tayesaitrall 12
# Generation  189    Average Fitness Score  1.798326359832636   ziocec tayssaitcall   11 ziocec tayesaktrall 11
# Generation  190    Average Fitness Score  1.806438127090301   ziocec tayesaitrall   12 zioccc tayesaitcall 11
# Generation  191    Average Fitness Score  1.8145363408521302   ziocec tayesaitlall   12 ziocec tayesaitryll 11
# Generation  192    Average Fitness Score  1.8226210350584306   ziocec tahesaitrall   12 ziocec tayesaitlalu 11
# Generation  193    Average Fitness Score  1.8306922435362802   jiocea tayesaitcall   12 ziocme tayesaitcall 11
# Generation  194    Average Fitness Score  1.83875   jiocec tayesaitjall   12 jiocec tayesaitcael 11
# Generation  195    Average Fitness Score  1.8467943380516236   ziosee tayesaitlyll   11 zircec tayesaitcall 12
# Generation  196    Average Fitness Score  1.8548252911813643   zircew tahesaitrall   12 ziocec tayasaitcall 11
# Generation  197    Average Fitness Score  1.8628428927680798   ziodec tayesaitcall   12 jiocea tahesaitrxll 11
# Generation  198    Average Fitness Score  1.8708471760797343   ziocec tayesaptcall   11 jiocea tayesaitxall 12
# Generation  199    Average Fitness Score  1.878838174273859   jiocea tabesaitcall   12 jiocea wayesaitxall 11
# Generation  200    Average Fitness Score  1.886401326699834   zioseeitayesaitcall   11 zircec tayesavtcall 11
# Generation  201    Average Fitness Score  1.8951946975973488   ziecec tayesaitcall   12 zincec tahesaitrall 13
# Generation  202    Average Fitness Score  1.903973509933775   pincec tayesaitcall   13 uircec tahesaitrall 12
# Generation  203    Average Fitness Score  1.912737799834574   pincec tahesaitralr   12 zincec tayesaitpall 13
# Generation  204    Average Fitness Score  1.9210743801652892   zincec taynsaitcall   12 pincec tayesastpall 12
# Generation  205    Average Fitness Score  1.9298100743187447   zincec tayeseitcall   13 ppncec tayesaitpall 12
# Generation  206    Average Fitness Score  1.938118811881188   zincec tayeseitcjll   12 zincec tahbsaitrall 12
# Generation  207    Average Fitness Score  1.94641384995878   zincec tayesattpall   12 zincec tayeseitcill 12
# Generation  208    Average Fitness Score  1.9551070840197693   zincec tayeseitcakl   12 zincec tayesaitjall 13
# Generation  209    Average Fitness Score  1.9637860082304526   zincec tazesaitrall   13 zincmc tayesaitjall 12
# Generation  210    Average Fitness Score  1.972450657894737   zincet tazesaitrall   13 zincec qayesaitpall 12
# Generation  211    Average Fitness Score  1.9806902218570255   zincet tazdsaitrall   12 zincec tazesaitrbll 12
# Generation  212    Average Fitness Score  1.9889162561576355   zincec tayesautcall   12 pincec tahesaisrall 12
# Generation  213    Average Fitness Score  1.997949138638228   iincec tayesaitpall   13 zincec tayeshitcall 13
# Generation  214    Average Fitness Score  2.0065573770491802   zincec tazesaitrall   13 zincet tayeshitcaln 12
# Generation  215    Average Fitness Score  2.015151515151515   zincec tazeshitrall   13 zincet tayebaitjall 12
# Generation  216    Average Fitness Score  2.023731587561375   eincec tazesaitrall   13 zigcet tazesaitrall 12
# Generation  217    Average Fitness Score  2.0322976287816843   pincec qazesaitrall   12 zincet tayeszitcall 13
# Generation  218    Average Fitness Score  2.0412581699346406   zinaet tahesaitrall   13 zincec tajeszitcall 13
# Generation  219    Average Fitness Score  2.049795918367347   zincec tayesaitcall   13 pincec tajekzitcall 12
# Generation  220    Average Fitness Score  2.057911908646003   ziccec tayeseitcall   12 zincec  azesaitrall 12
# Generation  221    Average Fitness Score  2.06601466992665   pincec tazevaitrall   12 elncec tayesaitcall 12
# Generation  222    Average Fitness Score  2.074104234527687   zipcec tazesaitrall   12 eincec tayeseitcakl 12
# Generation  223    Average Fitness Score  2.0825874694873883   zincec tayesaiteall   13 zixcec tayeshitcall 12
# Generation  224    Average Fitness Score  2.0910569105691055   zintec tajeszitcall   13 zincec tazesaisrall 12
# Generation  225    Average Fitness Score  2.099918765231519   zincec tazesaitgall   13 zincea tajeszitcall 13
# Generation  226    Average Fitness Score  2.1083603896103895   sincea tajeszitcall   13 zincec tajeszitcell 12
# Generation  227    Average Fitness Score  2.116382806163828   zincec qazesaitrall   12 zcncet tazeshitrall 12
# Generation  228    Average Fitness Score  2.124392220421394   eincecntayesaitcall   12 zincec iazesaitrall 12
# Generation  229    Average Fitness Score  2.1323886639676113   zincet tayesaineall   12 zincec tayeuzitcall 12
# Generation  230    Average Fitness Score  2.1407766990291264   pincec tayesaitcall   13 zincec tayesahtcall 12
# Generation  231    Average Fitness Score  2.149151172190784   zincet tajesnitcall   13 zintec tazesaitragl 12
# Generation  232    Average Fitness Score  2.1575121163166395   pincec tayesaitqall   13 zincec tayesaitcalt 12
# Generation  233    Average Fitness Score  2.16545601291364   zincec oajeszitcall   12 zincea wayesaitjall 12
# Generation  234    Average Fitness Score  2.1733870967741935   pincec fayesaitjall   12 zdncec tayesaitcall 12
# Generation  235    Average Fitness Score  2.1821112006446413   zincec tazesaitwall   13 einkec tahesaitrall 13
# Generation  236    Average Fitness Score  2.1904186795491145   einkec tejeszitcall   12 zincea tahesaiteall 13
# Generation  237    Average Fitness Score  2.1987127916331457   zincea tajeszitcyll   12 sincea tahesaiteall 13
# Generation  238    Average Fitness Score  2.2065916398713825   sincea tajhszitcall   12 sincea vahesaiteall 12
# Generation  239    Average Fitness Score  2.214859437751004   zdncec tayesaitjall   12 zincec tazeshitrall 13
# Generation  240    Average Fitness Score  2.2231139646869984   zincgc tahesaitrall   12 zincec tateshitrall 13
# Generation  241    Average Fitness Score  2.2313552526062552   zipcec tayesaitcall   12 kincec tateshitrall 13
# Generation  242    Average Fitness Score  2.2395833333333335   kincec tayesaitcalh   12 pinceo tateshitrall 13
# Generation  243    Average Fitness Score  2.2473979183346677   pinceo tajeszftcall   12 zintec  ateshitrall 12
# Generation  244    Average Fitness Score  2.2556   zincnt tazesaitgall   12 zincec tayesnitcall 13
# Generation  245    Average Fitness Score  2.26378896882494   zincec tayesaitqajl   12 pincec tayestitcall 13
# Generation  246    Average Fitness Score  2.271964856230032   pincec tayesaiteall   13 zincec tayestitcawl 12
# Generation  247    Average Fitness Score  2.2801276935355146   xincec tahesaiteall   13 sincea tazeshvtrall 12
# Generation  248    Average Fitness Score  2.2886762360446573   zincec tayessitcall   13 zincec tajesbitcall 13
# Generation  249    Average Fitness Score  2.296414342629482   zincec tayesamtpall   12 iincec tajesbitcadl 12
# Generation  250    Average Fitness Score  2.304140127388535   zrncec tahesaiteall   12 zincea tayesaitpalb 12
# Generation  251    Average Fitness Score  2.3118536197295145   zincec tahxsaiteall   12 zincea nayesaitcall 12
# Generation  252    Average Fitness Score  2.3195548489666136   zincec tayeshitclll   12 zinchc tayeseitcall 12
# Generation  253    Average Fitness Score  2.3272438443208894   zincec tahezaiteall   12 sincea tazeshitralk 12
# Generation  254    Average Fitness Score  2.3353174603174605   zincea tateshitvall   13 zincbc tahesaiteall 12
# Generation  255    Average Fitness Score  2.343774781919112   zincec tazesaitrall   13 eincec tazessitrall 13
# Generation  256    Average Fitness Score  2.3514263074484942   eincec tateshitraal   12 pinceo tazessitrzll 12
# Generation  257    Average Fitness Score  2.3590657165479016   zincec tatvshitrall   12 pinceo tayesavteall 12
# Generation  258    Average Fitness Score  2.3666930379746836   zincxa tayeshitcall   12 zincec tahesayteall 12
# Generation  259    Average Fitness Score  2.3743083003952568   zintec tahqsaitrall   12 zqncec tajeszitcall 12
# Generation  260    Average Fitness Score  2.382306477093207   pincwc tayessitcall   12 zincec tayesaitcall 13
# Generation  261    Average Fitness Score  2.389897395422257   zinctc tazeshitrall   12 zi cec tayesaitcall 12
# Generation  262    Average Fitness Score  2.3974763406940065   zintbc tayeshitcall   12 zinchc tajeszitcall 12
# Generation  263    Average Fitness Score  2.405043341213554   sincea tayesaiteafl   12 pincec tqjeszitcall 12
# Generation  264    Average Fitness Score  2.412992125984252   zincec tahesciteall   13 xigcec tazesaitwall 12
# Generation  265    Average Fitness Score  2.420535011801731   einkec taygsaitpall   12 zincec tahesaitrail 12
# Generation  266    Average Fitness Score  2.428066037735849   zincec tajosbitcall   12 zincec tayesaitpalu 12
# Generation  267    Average Fitness Score  2.4355852317360567   sincea tayesaitpsll   12 zincec tajevzitcall 12
# Generation  268    Average Fitness Score  2.4434850863422293   zincec taeeshitrall   13 kincec tayishitcall 12
# Generation  269    Average Fitness Score  2.4513725490196077   zcncec tajeszitcall   12 zincec taieshitcall 13
# Generation  270    Average Fitness Score  2.458855799373041   zincecdtayessitcall   12 zincec gaieshitcall 12
# Generation  271    Average Fitness Score  2.467110415035239   sinlea tayessitcall   13 zincec tajeszitsall 13
# Generation  272    Average Fitness Score  2.474569640062598   zincuc tayeszitcall   12 zincet tajeszits ll 12
# Generation  273    Average Fitness Score  2.482017200938233   zincec tazersitrall   12 eiacec tazeshitrall 12
# Generation  274    Average Fitness Score  2.48984375   iincec tayesaiqjall   12 zincec tayeszitpall 13
# Generation  275    Average Fitness Score  2.4972677595628414   zincec tajcszitcall   12 zincea tayeszktpall 12
# Generation  276    Average Fitness Score  2.504680187207488   zincec tajeszitcpll   12 zincea tazepaitrall 12
# Generation  277    Average Fitness Score  2.5120810600155883   eincjc tazeshitrall   12 zincbc tazessitrall 12
# Generation  278    Average Fitness Score  2.520249221183801    incec tayesaiteall   13 zincec tazeshitrall 13
# Generation  279    Average Fitness Score  2.5280155642023345   zincec tatessitrall   13 kincec tazeshotrall 12
# Generation  280    Average Fitness Score  2.535381026438569   eincec tahdsaiteall   12 xincec tazessitraln 12
# Generation  281    Average Fitness Score  2.543123543123543   eincec tayesaitpall   13 pincec tazessitrala 12
# Generation  282    Average Fitness Score  2.5504658385093166   zincec taeeohitrall   12 zibcec tateshitrall 12
# Generation  283    Average Fitness Score  2.5581846392552365   iincec tphesaitrall   12 zinaed tayesaitpall 13
# Generation  284    Average Fitness Score  2.565503875968992   zunaed tazesaitrall   12 zincec tayesaitpalw 12
# Generation  285    Average Fitness Score  2.573199070487994   kincec tazesaitraol   12 zincet tateshitiall 13
# Generation  286    Average Fitness Score  2.5804953560371517   zincet tatrshitvall   12 zincea tateshitiajl 12
# Generation  287    Average Fitness Score  2.587780355761794   einkec tayeszixcall   12 zincet tahebaitrall 12
# Generation  288    Average Fitness Score  2.5954404945904175   zincec tayesaitrall   13 zincuc tahesciteall 12
# Generation  289    Average Fitness Score  2.603088803088803   eincec tateshitzall   13 zincea tazesactrall 12
# Generation  290    Average Fitness Score  2.6103395061728394   epncec tahesciteall   12 zincec tazesainrall 12
# Generation  291    Average Fitness Score  2.617964533538936   zincecqtazesaitrall   12 zincec ta eshitrall 13
# Generation  292    Average Fitness Score  2.6251926040061635   zinctc tayesaiteall   12 pincec ta eshctrall 12
# Generation  293    Average Fitness Score  2.632409545804465   zincec tatemhitrall   12 pinceoxtazeshitrall 12
# Generation  294    Average Fitness Score  2.6403846153846153   sincea tayesniteall   13  incec tahesaiteall 13
# Generation  295    Average Fitness Score  2.647963105303613    incec tayeszitcall   13 zincet tahcsaiteall 12
# Generation  296    Average Fitness Score  2.655145929339478   zizcec tazesaitrall   12 zincec tazeshicrall 12
# Generation  297    Average Fitness Score  2.662701458173446   kincec tazusaitrall   12 zincef tateshitrall 13
# Generation  298    Average Fitness Score  2.670628834355828   zincef taresaitqall   13 pineec tateshitrall 13
# Generation  299    Average Fitness Score  2.6777777777777776   pioeec tajeszitcall   12 zifcea tateshitrall 12
# Generation  300    Average Fitness Score  2.6852986217457886   zinaet tajeszitcall   13 zincea tahesaitralf 12
# Generation  301    Average Fitness Score  2.6931905126243305   zincec tazesaitmall   13 zinces tayeshitcall 13
# Generation  302    Average Fitness Score  2.7006880733944953   zinces taeeshitrlll   12 zincez tayeshitcall 13
# Generation  303    Average Fitness Score  2.708174178762414   zoncez taeeshitrall   12 zincec tayeshitcall 13
# Generation  304    Average Fitness Score  2.7156488549618323   zincec tayesaitcall   13  vncec tayeshitcall 12
# Generation  305    Average Fitness Score  2.7227307398932115   zincsc tateshitiall   12 zigcet tayesaitjall 12
# Generation  306    Average Fitness Score  2.729801829268293   eibkec tayesaitcall   12 zincec tahesaitralo 12
# Generation  307    Average Fitness Score  2.7372429550647372   zincei tazesaitrall   13 zincec yayeszitcall 12
# Generation  308    Average Fitness Score  2.7442922374429224    incec tajeszytcall   12 shncea tayesaiteall 12
# Generation  309    Average Fitness Score  2.7517110266159697   zincecgtazeshitrall   12 ziniec tazeshitrall 13
# Generation  310    Average Fitness Score  2.7587386018237083   ziniec  ateshitrall   12 pinceo tazeshitralz 12
# Generation  311    Average Fitness Score  2.7661351556567957   zincec tahesaitralz   12 einkeo tajeszitsall 13
# Generation  312    Average Fitness Score  2.7735204855842186   ninkeo tayesaitcall   13 zincsc tajeszitsall 12
# Generation  313    Average Fitness Score  2.7808946171341926   zincec tayesaktpall   12 zinaed tayesaitoall 13
# Generation  314    Average Fitness Score  2.7882575757575756   zinaed tazesaitkall   13 zincec tayexaitoall 12
# Generation  315    Average Fitness Score  2.795230885692657   zintec taykszitcall   12 zincet tajeszincall 12
# Generation  316    Average Fitness Score  2.802571860816944   zincec tagesaitqall   13 zincef tazeshinrall 12
# Generation  317    Average Fitness Score  2.8095238095238093   zincec tyyeszitcall   12  incec tazeshitrazl 12
# Generation  318    Average Fitness Score  2.816842900302115   zi cec tayeszitcall   12 zincet tayescitcall 13
# Generation  319    Average Fitness Score  2.8237735849056604   zincet taeeshiqrall   12 zincec tayescitc ll 12
# Generation  320    Average Fitness Score  2.8310708898944195   zinces tateshitzall   13 einctc tazesaitgall 12
# Generation  321    Average Fitness Score  2.83835719668425   zincec tazesaitrull   12 zincek tazesaitgall 13
# Generation  322    Average Fitness Score  2.8452560240963853   zincek tayeszitcalu   12  incecitazesaitgall 12
# Generation  323    Average Fitness Score  2.8521444695259595   zincec tajeszitcalg   12 zinaet tajrszitcall 12
# Generation  324    Average Fitness Score  2.8597744360902255   zincec talesaitpall   13 iincec tayesqitcall 13
# Generation  325    Average Fitness Score  2.867017280240421   iincec tajesvitsall   13 zincec twyesqitcall 12
# Generation  326    Average Fitness Score  2.874249249249249   eincec tayeshetcall   12 zincec tateshitzall 13
# Generation  327    Average Fitness Score  2.8810952738184548   zincec tajeszitcakl   12 zinaet tateshimzall 12
# Generation  328    Average Fitness Score  2.8879310344827585   iincec tpyeszitcall   12  incec zayesaitpall 12
# Generation  329    Average Fitness Score  2.8947565543071163   zincec uayesaitpall   12 iincecdtayeshitcall 12
# Generation  330    Average Fitness Score  2.9019461077844313    zncec tateshitrall   12 pinbeo tahesaiteall 13
# Generation  331    Average Fitness Score  2.9087509349289453   pinbeo tjjeszitcall   12 zincec tahusaiteall 12
# Generation  332    Average Fitness Score  2.9162929745889388   zincec tajesziteall   13 zincec tazesaitfall 13
# Generation  333    Average Fitness Score  2.923076923076923   zincec tajeszitcrll   12 zintec tazesaftfall 12
# Generation  334    Average Fitness Score  2.930597014925373   zincec tazesaitmall   13 zincec taleshitrall 13
# Generation  335    Average Fitness Score  2.9377330350484714   zincem taeeshitrall   13 zincec taleshiwrall 12
# Generation  336    Average Fitness Score  2.945230998509687   tincec tateshitrall   13 kincec tayestitcall 13
# Generation  337    Average Fitness Score  2.9519731943410275   kincecktaeeshitrall   12 zincec tayestidcall 12
# Generation  338    Average Fitness Score  2.959077380952381   zincec tajeszytcall   12 zintec tazesuitwall 13
# Generation  339    Average Fitness Score  2.9657992565055764   zintec tayeshitcarl   12 zinces tazesuntwall 12
# Generation  340    Average Fitness Score  2.972882615156018   zinaed tazesnitrall   13 zihcec tazesaitkall 12
# Generation  341    Average Fitness Score  2.979955456570156   xincec taoeszitcall   13 zinaet tahelaiteall 12
# Generation  342    Average Fitness Score  2.9870178041543025   ziscec tajeszitsall   12 einkeo tazesritrall 13
# Generation  343    Average Fitness Score  2.994069681245367   einkeo taeeshitnall   13 zlncec tazesritrall 12
# Generation  344    Average Fitness Score  3.0011111111111113   zincec tajeszitcasl   12 zincec tayesaitcall 13
# Generation  345    Average Fitness Score  3.0077720207253886   zinchc tayesaitrall   12 zincec tayzsaitcall 12
# Generation  346    Average Fitness Score  3.014423076923077   pincec tayejaitcall   12 zoncec tayesaitqall 12
# Generation  347    Average Fitness Score  3.0210643015521064   zincec tayessilcall   12 z ncec tazeshitrall 12
# Generation  348    Average Fitness Score  3.0280649926144756   pincbc tajeszitcall   12 sincea tayesaitqall 13
# Generation  349    Average Fitness Score  3.034686346863469   sincea tayeizitpall   12 zincec tayesaitqazl 12
# Generation  350    Average Fitness Score  3.0416666666666665   eincecctayesaitpall   12 zinaed tazesfitrall 13
# Generation  351    Average Fitness Score  3.0486366985998528   iinaed tayesaiteall   13 zincec tazesfitrabl 12
# Generation  352    Average Fitness Score  3.0555964653902796   zincecptajeszitcall   12 zincea tazesxitgall 13
# Generation  353    Average Fitness Score  3.062178072111847   zincea tazesaitmwll   12 zincec tazesxitgala 12
# Generation  354    Average Fitness Score  3.06875   zincec tayessitcasl   12 zincec tazesaftwall 12
# Generation  355    Average Fitness Score  3.0756796473181485   einkec tazesaitwalu   12 zinces tahesaitrall 13
# Generation  356    Average Fitness Score  3.0822320117474304   zinces tazesaitrsll   12 zincei tahesaitraly 12
# Generation  357    Average Fitness Score  3.0887747615553924   zincet tahesaiteals   12 ziicea tajesnitcall 12
# Generation  358    Average Fitness Score  3.095674486803519   sincea tahesaiteall   13 einkec taheeaiteall 12
# Generation  359    Average Fitness Score  3.102930402930403   zinpec tahesaiteall   13 zincea tageskitqall 13
# Generation  360    Average Fitness Score  3.1101756954612005   ziniea tahesaiteall   13 zinlea tageskitqall 13
# Generation  361    Average Fitness Score  3.1170446232626188   jinlea tahesaiteall   13 zinceaitageskitqall 12
# Generation  362    Average Fitness Score  3.12390350877193   zincec tajesjiteall   13 zincoc tazeshitrall 12
# Generation  363    Average Fitness Score  3.1307523739956173   zlncet tayesnitcall   12 zinjec tajesnitcall 13
# Generation  364    Average Fitness Score  3.1375912408759126   zinjec tazssaitfall   12 zinceb tajesnitcall 13
# Generation  365    Average Fitness Score  3.1444201312910285   zincea tayesaitpall   13 zinaed tajeynitcall 12
# Generation  366    Average Fitness Score  3.1508746355685133   sinlea ua eshitrall   12 zincec tayessihcall 12
# Generation  367    Average Fitness Score  3.15768390386016   zincec tatesaitgall   13 zincek naieshitcall 12
# Generation  368    Average Fitness Score  3.1648471615720526   zincek tahpsaiteall   12 pinbeo tazes itgall 14
# Generation  369    Average Fitness Score  3.1716363636363636   pivbeo tateshitiall   12 zincet tazns itgall 13
# Generation  370    Average Fitness Score  3.178779069767442   pinbeo tahns itgall   13 zimcet tazes itgall 13
# Generation  371    Average Fitness Score  3.1855482933914305   pinbeo tazes icgall   13 zimcet tazec itgall 12
# Generation  372    Average Fitness Score  3.193033381712627   pingeo tayestitcall   13 kincec tahes itgall 14
# Generation  373    Average Fitness Score  3.2008701957940535   kinuec tazes itgall   14 pinbeh tahes itgall 14
# Generation  374    Average Fitness Score  3.2083333333333335   pinbehytahes itgall   13 qincec tahes itgall 14
# Generation  375    Average Fitness Score  3.215423606082549   qincec  azes itgall   13 pinbeo uahes itgall 13
# Generation  376    Average Fitness Score  3.222865412445731   qincec taxes itgall   14 pinbeh tahes ztgall 13
# Generation  377    Average Fitness Score  3.230296456977585   gincec tahes itgall   14 qincec taxen itgall 13
# Generation  378    Average Fitness Score  3.2373554913294798   gincec taxes itgals   13 qbncec tahes itgall 13
# Generation  379    Average Fitness Score  3.244404332129964   pinbeo taxes gtgall   13 qincecvtazes itgall 13
# Generation  380    Average Fitness Score  3.251803751803752   pinbeo tahes iqgall   13 gincec taues itgall 14
# Generation  381    Average Fitness Score  3.2591925018024512   gincec tahes wtgall   13 gincec taues itqall 14
# Generation  382    Average Fitness Score  3.26657060518732   gincec tahez itgall   13 qincec taues itqall 14
# Generation  383    Average Fitness Score  3.273938084953204   qincec tahes ityall   14 gincec kaues itqall 13
# Generation  384    Average Fitness Score  3.280935251798561   pinbeo tahes itgjll   13 kitcec tazes itgall 13
# Generation  385    Average Fitness Score  3.2882818116462977   qincec taxes itgall   14 qincec tahes itgasl 13
# Generation  386    Average Fitness Score  3.2952586206896552   kincec taues itqqll   13 gincec tahesnitgall 13
# Generation  387    Average Fitness Score  3.302943287867911   jinbeo taues itqall   14 qincec tazes itgall 14
# Generation  388    Average Fitness Score  3.3102582496413198   qincec tahes itgaml   13 qincec ta es itgall 14
# Generation  389    Average Fitness Score  3.317562724014337   qincec tahe  ityall   13 qincec ta es itgall 14
# Generation  390    Average Fitness Score  3.3244985673352434   qincec taxes itgxll   13 qincec ta esuitgall 13
# Generation  391    Average Fitness Score  3.331782390837509   qincec tahes etgall   13 gincec tapes itqall 14
# Generation  392    Average Fitness Score  3.338698140200286   gincec paxes itgall   13 qincec tapis itqall 13
# Generation  393    Average Fitness Score  3.345961401000715   pgnbeo taues itqall   13 jinbeo tazes itcall 14
# Generation  394    Average Fitness Score  3.353214285714286   jinaeo taues itqall   14 jinbeo tazes itcayl 13
# Generation  395    Average Fitness Score  3.3604568165596005   kinueu ta es itgall   14 qincec tazes itgcll 13
# Generation  396    Average Fitness Score  3.3673323823109844   punbeh ta es itgall   13 qjncec tahes itgall 13
# Generation  397    Average Fitness Score  3.3749109052031363   qincef tazes itgall   14 pinbep tahes itgall 14
# Generation  398    Average Fitness Score  3.382122507122507   pisbep ta es itgall   13 qincec tades itgall 14
# Generation  399    Average Fitness Score  3.38932384341637   qircec ta es itgall   13 qinpec tades itgall 14
# Generation  400    Average Fitness Score  3.3961593172119486   qinpec iaxes itgall   13 qincec tadcs itgall 13
# Generation  401    Average Fitness Score  3.4033404406538734   pinbeh tahes ituall   14 qincec xahes itgall 13
# Generation  402    Average Fitness Score  3.41015625   gincecctazes itcall   13 jinbeo taues mtgall 13
# Generation  403    Average Fitness Score  3.416962384669979   kincec ta es itga l   13 qincec tahes atgall 13
# Generation  404    Average Fitness Score  3.424113475177305   mincec tahes itgall   14 kincec taxns itgall 13
# Generation  405    Average Fitness Score  3.430900070871722   gincec tszes itgall   13 pinbeo taues isgall 13
# Generation  406    Average Fitness Score  3.438385269121813   gincec taues itrall   14 qincec taues itsall 14
# Generation  407    Average Fitness Score  3.445859872611465   qincec ta es ittall   14 kinqeu taues itsall 14
# Generation  408    Average Fitness Score  3.4526166902404527   kinqeu tadeshitgall   13 qinpec taues itshll 13
# Generation  409    Average Fitness Score  3.4597173144876323   fincec tades itgall   14 qinpec tpxes itgall 13
# Generation  410    Average Fitness Score  3.46680790960452   jinbeo tazes itsall   14 qincecutazes itcall 13
# Generation  411    Average Fitness Score  3.4735356386732534   qinpec tahen ituall   13 pinbeh tadis itgall 13
# Generation  412    Average Fitness Score  3.4802538787023978   qincec kazes itgall   13 pinbeo tgxes itgall 13
# Generation  413    Average Fitness Score  3.4873150105708244   qcncec taxes itgall   13 qincec tazes itjall 14
# Generation  414    Average Fitness Score  3.494014084507042   qincec tazes itcxll   13 jinbeo tazes itjxll 13
# Generation  415    Average Fitness Score  3.500703729767769   qdncec taues itrall   13 gincec tahes ityell 13
# Generation  416    Average Fitness Score  3.507383966244726   pinbeh tahes itgalm   13 gincec tahes ftgall 13
# Generation  417    Average Fitness Score  3.5144061841180605   qincec tahps itgall   13 sincec ta es itgall 14
# Generation  418    Average Fitness Score  3.521067415730337   sincec tazes itgalk   13 pinbeo tq es itgall 13
# Generation  419    Average Fitness Score  3.5280701754385966   qincec tlzes itgall   13 qinmef ta es itgall 14
# Generation  420    Average Fitness Score  3.5347124824684433   qinmyf tazes itgall   13 qincef ta es izgall 13
# Generation  421    Average Fitness Score  3.541345480028031   qincwc taues itsall   13 kicqeu tahes itgall 13
# Generation  422    Average Fitness Score  3.5483193277310923   ginaec tahes ityall   14 qincecvtahes itgall 13
# Generation  423    Average Fitness Score  3.554933519944017   jinaeo tahek ityall   13 qincec taues ktqall 13
# Generation  424    Average Fitness Score  3.561888111888112   qincec tahes ittall   14 piqbeh ta es ittall 13
# Generation  425    Average Fitness Score  3.56848357791754   jqnaeo tazes itgall   13 qmncef taues itqall 13
# Generation  426    Average Fitness Score  3.5750698324022347   gincec taxes itgxll   13 qincec taues itgaql 13
# Generation  427    Average Fitness Score  3.5819958129797627   nincec tahes itgall   14 gincec tauzs itqall 13
# Generation  428    Average Fitness Score  3.588563458856346   pinbep ta qs itgall   13 qincec tahes ivgall 13
# Generation  429    Average Fitness Score  3.5958188153310107   jinceo tahes ityall   14 qincec tazes itsall 14
# Generation  430    Average Fitness Score  3.602367688022284   qincbc tazes itjall   13 qincecztazes itsall 13
# Generation  431    Average Fitness Score  3.608907446068198   pinbeo tauesnitsall   13 kinqeu tazes gtgall 13
# Generation  432    Average Fitness Score  3.6154381084840055   kijuec taues itqall   13 jinaeo tazes itgalc 13
# Generation  433    Average Fitness Score  3.6223071577484363   qincec taues itgalq   13 gincec taxes itdall 14
# Generation  434    Average Fitness Score  3.629166666666667   gincec baues itsall   13 qincec taxes itdall 14
# Generation  435    Average Fitness Score  3.6360166551006246   qinceg tahes ituall   14 pinbeh taxesoitdall 13
# Generation  436    Average Fitness Score  3.642857142857143   gincecdtazes itgall   13 kinuec taues itvall 14
# Generation  437    Average Fitness Score  3.6496881496881497   kinuec taues ituall   14 gincec daues itvall 13
# ...
# Generation  572    Average Fitness Score  4.620405576679341   wdnweq takes it all   16 minwes takes it all 16
# Generation  573    Average Fitness Score  4.62761241291957   winxe  takeq it all   16 winbem takes rt all 16
# Generation  574    Average Fitness Score  4.635126582278481   win e  takesjit all   16 winwes takes it all 17
# Generation  575    Average Fitness Score  4.642314990512334   winwes takes itvall   16 winwes zakes it all 16
# Generation  576    Average Fitness Score  4.649494310998736   winbesmtakes it all   16 win s  takes it all 16
# Generation  577    Average Fitness Score  4.65698041692988   winwez takes it all   17 winbe  takesqit all 16
# Generation  578    Average Fitness Score  4.664141414141414   winbes takes it als   16 win e  yakes it all 16
# Generation  579    Average Fitness Score  4.671293375394321   winwes zakes it all   16 ainwes takes it all 16
# Generation  580    Average Fitness Score  4.67843631778058   winwes takes dt all   16 winwls takes it all 16
# Generation  581    Average Fitness Score  4.685570258349086   winwes takes et all   16 winxe  takes it oll 16
# Generation  582    Average Fitness Score  4.692695214105793   winbes takes lt all   16 winwez takeb it all 16
# Generation  583    Average Fitness Score  4.699811202013845   cinbes takes it all   16 winwes thkes it all 16
# Generation  584    Average Fitness Score  4.706918238993711    inxe  takes it all   16 ninwez takes it all 16
# Generation  585    Average Fitness Score  4.714330609679447   winwet takes it all   17 winbem takfs it all 16
# Generation  586    Average Fitness Score  4.72141959798995   wizwes takes it all   16 wunbes takes it all 16
# Generation  587    Average Fitness Score  4.7284996861268045   winwez takes it aly   16 wibae  takes it all 16
# Generation  588    Average Fitness Score  4.735884567126726   winbex takes it all   17 w nwes takes it all 16
# Generation  589    Average Fitness Score  4.743260188087774   winbem takes it vll   16 winwes takes it all 17
# Generation  590    Average Fitness Score  4.75062656641604   winwes takes it abl   16 winaez takes it all 17
# Generation  591    Average Fitness Score  4.757670632435818   vinaez takes it all   16 winwet cakes it all 16
# Generation  592    Average Fitness Score  4.764705882352941   winwes taoes it all   16 winwes makes it all 16
# Generation  593    Average Fitness Score  4.771732332707942   winbem takzs it all   16 winwez takes it akl 16
# Generation  594    Average Fitness Score  4.77875   winbem takus it all   16 winwez takes it alz 16
# Generation  595    Average Fitness Score  4.78575890068707   winbex takes tt all   16 winaez taees it all 16
# Generation  596    Average Fitness Score  4.792759051186017   winae  tabes it all   16 wiqwes takes it all 16
# Generation  597    Average Fitness Score  4.799750467872738   wipwes takes it all   16 cinbex takes it all 16
# Generation  598    Average Fitness Score  4.806733167082294   winwez takesyit all   16 winbe  takes it jll 16
# Generation  599    Average Fitness Score  4.813707165109034   winwes takgs it all   16 winbes takes it alm 16
# Generation  600    Average Fitness Score  4.820983810709838   wnnbex takes it all   16 winee  takes it all 17
# Generation  601    Average Fitness Score  4.828251400124455   wineeq takes it all   17 winaez tfkes it all 16
# Generation  602    Average Fitness Score  4.835199004975125   win e  taken it all   16 winbes takes itjall 16
# Generation  603    Average Fitness Score  4.84213797389683   wivaez takes it all   16 winbes takrs it all 16
# Generation  604    Average Fitness Score  4.849378881987578   winweq takes it yll   16 winwes takes it all 17
# Generation  605    Average Fitness Score  4.856610800744879   winwesetakes it all   16 wince  takes it all 17
# Generation  606    Average Fitness Score  4.863523573200992   wxnce  takes it all   16 winwes takes it ale 16
# Generation  607    Average Fitness Score  4.87042777433354   wvnwet takes it all   16 w nee  takes it all 16
# Generation  608    Average Fitness Score  4.877633209417596   winbex takes it ajl   16 winyeq takes it all 17
# Generation  609    Average Fitness Score  4.8845201238390095   winyoq takes it all   16 winbd  takes it all 16
# Generation  610    Average Fitness Score  4.891707920792079   winwes takes it adl   16 winbeh takes it all 17
# Generation  611    Average Fitness Score  4.898577612863327   winbeh tates it all   16 wineeq takes it alg 16
# Generation  612    Average Fitness Score  4.905438813349814   winaez takes it nll   16 winbes takes ii all 16
# Generation  613    Average Fitness Score  4.912291537986412   winwes tases it all   16 winbes takes it ael 16
# Generation  614    Average Fitness Score  4.919444444444444   win e  takes it all   17 winwet tlkes it all 16
# Generation  615    Average Fitness Score  4.92658852560148   wineeq tapes it all   16 winves takes it all 17
# Generation  616    Average Fitness Score  4.933415536374846   winves takes it akl   16 wince  takes it dll 16
# Generation  617    Average Fitness Score  4.940234134319162   winae  takes itaall   16 winbesqtakes it all 16
# Generation  618    Average Fitness Score  4.947044334975369   wixwes takes it all   16 wineeq takes it ail 16
# Generation  619    Average Fitness Score  4.953846153846154   win e  takes it tll   16 wynwes takes it all 16
# Generation  620    Average Fitness Score  4.960639606396064   winwes takes it ajl   16 winbwm takes it all 16
# Generation  621    Average Fitness Score  4.967732022126613   winiem takes it all   17 winbex takss it all 16
# Generation  622    Average Fitness Score  4.974508599508599   wsnbe  takes it all   16 winbem takes it alg 16
# Generation  623    Average Fitness Score  4.981276856967464   wilee  takes it all   16 winxe  takxs it all 16
# Generation  624    Average Fitness Score  4.988036809815951   winyeq takes it alr   16 wineeq takus it all 16
# Generation  625    Average Fitness Score  4.994788473329246   winee  takes it alc   16 win e ntakes it all 16
# Generation  626    Average Fitness Score  5.001531862745098   winbeh takes pt all   16 winwes takes itsall 16
# Generation  627    Average Fitness Score  5.008266993263931   winbex takes itmall   16 winae  takes pt all 16
# Generation  628    Average Fitness Score  5.0149938800489595   winee  takesfit all   16 winyeq takesnit all 16
# Generation  629    Average Fitness Score  5.0217125382263   wineeq takey it all   16 wnnyeq takes it all 16
# Generation  630    Average Fitness Score  5.028422982885085   winee  tskes it all   16 winves takbs it all 16
# Generation  631    Average Fitness Score  5.035125229077581   winbe  tzkes it all   16 winbes takez it all 16
# Generation  632    Average Fitness Score  5.041819291819292   winbes takzs it all   16 winbeh tukes it all 16
# Generation  633    Average Fitness Score  5.048505186089079   winbe  takes it akl   16 winyeq taken it all 16
# Generation  634    Average Fitness Score  5.055182926829269   winwes takes itmall   16 winwes oakes it all 16
# Generation  635    Average Fitness Score  5.0618525289457645   wgnce  takes it all   16 winbem takes it alb 16
# Generation  636    Average Fitness Score  5.068514007308161   winyeq takes ithall   16 whnwes takes it all 16
# Generation  637    Average Fitness Score  5.0754716981132075   winxe  takel it all   16 winaes takes it all 17
# Generation  638    Average Fitness Score  5.0821167883211675   winaes tares it all   16 winves takes it alo 16
# Generation  639    Average Fitness Score  5.088753799392097   winbes takss it all   16 winwes takes it ala 16
# Generation  640    Average Fitness Score  5.095382746051032   winaezhtakes it all   16 winae  takes iu all 16
# Generation  641    Average Fitness Score  5.10200364298725   winwet ta es it all   16 winbem takes itlall 16
# Generation  642    Average Fitness Score  5.108616504854369   aineeq takes it all   16 winaez tpkes it all 16
# Generation  643    Average Fitness Score  5.1152213462704665   winaw  takes it all   16 nince  takes it all 16
# Generation  644    Average Fitness Score  5.121818181818182   winee  takes it azl   16 w n e  takes it all 16
# Generation  645    Average Fitness Score  5.128709872804361   winzes takes it all   17 winwwz takes it all 16
# Generation  646    Average Fitness Score  5.135593220338983   winbea takes it all   17 winwez takes it alt 16
# Generation  647    Average Fitness Score  5.142468239564428   winbex takes it all   17 xinwez takes it all 16
# Generation  648    Average Fitness Score  5.149032648125756   wineeq takhs it all   16 winbesutakes it all 16
# Generation  649    Average Fitness Score  5.155891238670695   winzex takes it all   17 wrnbes takes it all 16
# Generation  650    Average Fitness Score  5.16243961352657   winwes takel it all   16 winiem takes it ell 16
# Generation  651    Average Fitness Score  5.168980084490042   win e  takes it ajl   16 winbes pakes it all 16
# Generation  652    Average Fitness Score  5.175512665862485   winaez takes it al    16 win e  takesyit all 16
# Generation  653    Average Fitness Score  5.1820373719107895   winbex taoes it all   16 wdnee  takes it all 16
# Generation  654    Average Fitness Score  5.18855421686747   winaezktakes it all   16 winee  takes it alv 16
# Generation  655    Average Fitness Score  5.195364238410596   winbea nakes it all   16 win ei takes it all 17
# Generation  656    Average Fitness Score  5.201865222623345   win ei takesfit all   16 winee  takesnit all 16
# Generation  657    Average Fitness Score  5.2083583884546005   rinbe  takes it all   16 winweq takes rt all 16
# Generation  658    Average Fitness Score  5.21484375   win e  tgkes it all   16 wineeq takes it alk 16
# Generation  659    Average Fitness Score  5.221321321321321   win e  takes il all   16 witzex takes it all 16
# Generation  660    Average Fitness Score  5.2277911164465785   winwesptakes it all   16 winbes bakes it all 16
# Generation  661    Average Fitness Score  5.234853029394121   win e  takeb it all   16 winber takes it all 18
# Generation  662    Average Fitness Score  5.241606714628297   winbe  takes it all   17 dinbea takes it all 16
# Generation  663    Average Fitness Score  5.248651887357699   xinber takes it all   17 winieb takes it all 17
# Generation  664    Average Fitness Score  5.255688622754491   winber takes it aml   17 winieb takes it all 17
# Generation  665    Average Fitness Score  5.262417713943746   winber tokes it all   17 winieb takem it all 16
# Generation  666    Average Fitness Score  5.269138755980861   winber takes itkall   17 winbex takys it all 16
# Generation  667    Average Fitness Score  5.275851763299462   winber takes it oll   17 wio ei takes it all 16
# Generation  668    Average Fitness Score  5.282556750298686   ninber takes it all   17 winbex takeshit all 16
# Generation  669    Average Fitness Score  5.289253731343283   winber takes itmall   17 winbex takes io all 16
# Generation  670    Average Fitness Score  5.2959427207637235   winb r takes it all   17 winwes tabes it all 16
# Generation  671    Average Fitness Score  5.302623732856291   winber tabes it all   17 winwes takes nt all 16
# Generation  672    Average Fitness Score  5.309296781883194   winbfr takes it all   17 winaez takes is all 16
# Generation  673    Average Fitness Score  5.315961882072663   winber tases it all   17 winweqftakes it all 16
# Generation  674    Average Fitness Score  5.322619047619048   winber takes it alm   17 winwes taoes it all 16
# Generation  675    Average Fitness Score  5.329268292682927   winber takestit all   17 winee  takes iy all 16
# Generation  676    Average Fitness Score  5.335909631391201   winber tzkes it all   17 winwet nakes it all 16
# Generation  677    Average Fitness Score  5.342543077837195   winber tases it all   17 winbt  takes it all 16
# Generation  678    Average Fitness Score  5.34916864608076   winber taces it all   17 win ei takes it alz 16
# Generation  679    Average Fitness Score  5.355786350148368   winber trkes it all   17 winaes takesoit all 16
# Generation  680    Average Fitness Score  5.362396204033215   winber takes it aql   17 winee  takes it alf 16
# Generation  681    Average Fitness Score  5.369294605809128   winber tgkes it all   17 winfeq takes it all 17
# Generation  682    Average Fitness Score  5.375888625592417   winber takesiit all   17 winfeq takee it all 16
# Generation  683    Average Fitness Score  5.382474837181764   wiaber takes it all   17 winee  takas it all 16
# Generation  684    Average Fitness Score  5.3890532544378695   winbej takes it all   17 winee  takes itkall 16
# Generation  685    Average Fitness Score  5.395623891188646   winber takessit all   17 winwes takeh it all 16
# Generation  686    Average Fitness Score  5.402186761229315   wiwber takes it all   17 ninber takes ithall 16
# Generation  687    Average Fitness Score  5.4087418783225045   w nber takes it all   17 winbe  takesuit all 16
# Generation  688    Average Fitness Score  5.415584415584416   winber takes itaall   17 winbkr takes it all 17
# Generation  689    Average Fitness Score  5.42212389380531   winber takesqit all   17 winbkr taaes it all 16
# Generation  690    Average Fitness Score  5.428655660377358   winber takes ih aml   16 winber takes it ell 17
# Generation  691    Average Fitness Score  5.435179728933412   winber tazes it ell   16 wiqber takes it all 17
# Generation  692    Average Fitness Score  5.4416961130742045   winber uakes it all   17 wiqber tikes it all 16
# Generation  693    Average Fitness Score  5.448204826368452   winberptakes it all   17 winxe  takes ip all 16
# Generation  694    Average Fitness Score  5.4547058823529415   winberttakes it all   17 winbex takzs it all 16
# Generation  695    Average Fitness Score  5.461199294532628   winber takps it all   17 winwes takes it aly 16
# Generation  696    Average Fitness Score  5.467685076380729   winberitakes it all   17 ninber ta es it all 16
# Generation  697    Average Fitness Score  5.474163241338814   winber taked itmall   16 widber takes it all 17
# Generation  698    Average Fitness Score  5.480633802816901   winbermtakes it all   17 widber taket it all 16
# Generation  699    Average Fitness Score  5.487096774193549   winberhtakes it all   17 winbex takes itkall 16
# Generation  700    Average Fitness Score  5.493552168815944   rinber takes it all   17 winwes takes wt all 16
# Generation  701    Average Fitness Score  5.5   winber takesqit all   17 winaez takes it aln 16
# Generation  702    Average Fitness Score  5.506440281030445   winber takes vt all   17 wbnwes takes it all 16
# Generation  703    Average Fitness Score  5.512873025160912   winber takez it all   17 winbem takes it a l 16
# Generation  704    Average Fitness Score  5.519298245614035   winbek takes it alm   16 winbel takes it all 17
# Generation  705    Average Fitness Score  5.525715955581531   winber takes ft all   17 winbel takes iy all 16
# Generation  706    Average Fitness Score  5.532126168224299   winber takes ityall   17 winyeq takec it all 16
# Generation  707    Average Fitness Score  5.538820782253357   winter takes it all   18 wicbea takes it all 16
# Generation  708    Average Fitness Score  5.545507584597433   winter takes itsall   17 winber takes it jll 17
# Generation  709    Average Fitness Score  5.552186588921283   winbeo takes it all   17 wintqr takes it all 17
# Generation  710    Average Fitness Score  5.558857808857809   wiiber takes it all   17 winter takes zt all 17
# Generation  711    Average Fitness Score  5.565521258008154   winber takev it all   17 wintjr takes it all 17
# Generation  712    Average Fitness Score  5.572176949941793   winber takesfit all   17 wintnr takes it all 17
# Generation  713    Average Fitness Score  5.5788248981966255   winber taked it all   17 winter takes it ell 17
# Generation  714    Average Fitness Score  5.58546511627907   winter takes it alt   17 winber takes it hll 17
# Generation  715    Average Fitness Score  5.592097617664149   winber takes it ahl   17 wiwter takes it all 17
# Generation  716    Average Fitness Score  5.599303135888502   winner takes it all   19 winber takes ih all 17
# winner takes it all   winber takes it all
